# %%
import pandas as pd
import utilities as util
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Dataset

# %%
# Import papers spreadsheet to dataset
df_sms_extraction = pd.read_excel('../dataset/Extraction_form.xlsx')
df_sms_extraction.head(1)
# Out:
#    Paper Id           Citation Google Scholar  \
# 0         1  Perez et al. 2019              1
#
#                                         Authors  \
# 0  Boris Perez, Dario Correal, Hernan Astudillo
#
#                                                Title  Publication Year  \
# 0  A Proposed Model-driven Approach to Manage Arc...              2019
#
#                                             Abstract  Venue Type  \
# 0  Architectural Technical Debt (ATD) is a metaph...  Conference
#
#                                                Venue  \
# 0  2019 IEEE/ACM International Conference on Tech...
#
#                                        Name of Venue  ...  \
# 0  International Conference on Technical Debt (Te...  ...
#
#   Q4 (Calculate the cost)
#  yes - how?  \
# 0                                 NaN
#
#                                   Extra (Conclusion)  \
# 0  We have proposed a model-driven approach for m...
#
#                                Extra2 (Related work) Extra 3 (Important work)  \
# 0  Verdecchia in [16] proposed a technique focuse...                      NaN
#
#   Strong Aspects Weak Aspects Scientific Rigor Paper relevance Limitations  \
# 0            NaN          NaN              NaN             NaN         NaN
#
#   Future Works
# 0          NaN
#
# [1 rows x 29 columns]

# %%
df_sms_extraction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 29 columns):
# Paper Id                                   47 non-null int64
# Citation                                   47 non-null object
# Google Scholar                             47 non-null object
# Authors                                    47 non-null object
# Title                                      47 non-null object
# Publication Year                           47 non-null int64
# Abstract                                   47 non-null object
# Venue Type                                 47 non-null object
# Venue                                      47 non-null object
# Name of Venue                              47 non-null object
# Field                                      47 non-null object
# Key words                                  47 non-null object
# Number of Pages                            47 non-null int64
# Main aim (Goal)                            47 non-null object
# Techniques, approach, methods and tools    43 non-null object
# Kind of reasearch                          42 non-null object
# Q1 (Measure) yes - what?                  34 non-null object
# Q2 (Monitoring) yes - how?                23 non-null object
# Q3 (Techniques and Tools) yes - what?     32 non-null object
# Q4 (Calculate the cost) yes - how?        23 non-null object
# Extra (Conclusion)                         47 non-null object
# Extra2 (Related work)                      30 non-null object
# Extra 3 (Important work)                   11 non-null object
# Strong Aspects                             7 non-null object
# Weak Aspects                               7 non-null object
# Scientific Rigor                           9 non-null object
# Paper relevance                            9 non-null object
# Limitations                                9 non-null object
# Future Works                               8 non-null object
# dtypes: int64(3), object(26)
# memory usage: 10.7+ KB

# %% [markdown]
# ## 1.1 List of Analysed Papers

# %%
for item in zip(list(df_sms_extraction['Citation']), list(df_sms_extraction['Title'])):
    citation = item[0]
    title = ' '.join(item[1].split())
    print('({}, {})'.format(citation, title))
# Out:
# (Perez et al. 2019, A Proposed Model-driven Approach to Manage Architectural Technical Debt Life Cycle)
# (Martini et al 2017, A semi-automated framework for the identification and estimation of Architectural Technical Debt: A comparative case-study on the modularization of a software component)
# (Roveda et al. 2018, Towards an Architectural Debt Index)
# (Snipes et al. 2018, A Case Study of the Effects of Architecture Debt on Software Evolution Effort)
# (Nayebi et al. 2019, A Longitudinal Study of Identifying and Paying Down architecture debt)
# (Feng et al. 2019, Active Hotspot: An Issue-Oriented Model to Monitor Software Evolution and Degradation)
# (Li et al. 2014, An Empirical Investigation of Modularity Metrics for Indicating architectural technical debt)
# (Martini et al. 2016, An Empirically Developed Method to Aid Decisions on Architectural Technical Debt Refactoring: AnaConDebt)
# (Xiao et al. 2016, Identifying and Quantifying Architectural Debt)
# (Verdecchia 2018, Identifying Architectural Technical Debt in Android Applications through Automated Compliance Checking)
# (Zitzweitz et al. 2019, Mitigating Technical and Architectural Debt with Sonargraph Using static analysis to enforce architectural constraints)
# (Martini and Bosch 2017, On the interest of architectural technical debt: Uncovering the contagious debt phenomenon)
# (Fontana et al. 2016, Tool support for evaluating architectural debt of an existing system: An experience report)
# (Li et al. 2015, Architectural Technical Debt Identification based on Architecture Decisions and Change Scenarios)
# (Martini et al. 2014, Architecture Technical Debt: Understanding Causes and a Qualitative Model)
# (Martini et al. 2016, Estimating and Quantifying the Benefits of Refactoring to Improve a Component Modularity: a Case Study)
# (Martini et al. 2018, Identifying and Prioritizing Architectural Debt Through Architectural Smells: A Case Study in a Large Software Company)
# (Cai and Kazman 2016, Software Architecture Health Monitor)
# (Kazman et al. 2015, A Case Study in Locating the Architectural Roots of Technical Debt)
# (Martini and Bosch 2015, Towards Prioritizing Architecture Technical Debt: Information Needs of Architects and Product Owners)
# (Tommasel 2019, Applying Social Network Analysis Techniques to Architectural Smell Prediction)
# (Nord et al. 2012, In Search of a Metric for Managing Architectural Technical Debt)
# (Cai and Kazman 2019, DV8: Automated Architecture Analysis Tool Suites)
# (Skiada et al. 2018, Exploring the Relationship between Software Modularity and Technical Debt)
# (Eliasson et al. 2015, Identifying and Visualizing Architectural Debt and Its Efficiency Interest in the Automotive Domain: A Case Study)
# (Fontana et al. 2016, Technical Debt Indexes provided by tools: a preliminary discussion)
# (MacComark and Sturteant 2016, Technical debt and system architecture: The impact of coupling on defect-related activity)
# (Sas et al. 2019, Investigating Instability Architectural Smells Evolution: An Exploratory Case Study)
# (Fontana et al. 2019, PageRank and criticality of architectural smells)
# (Spinellis and Avgeriou 2019, Evolution of the Unix System Architecture: An Exploratory Case Study)
# (Izurieta et al. 2018, A position study to investigate technical debt associated with security weaknesses)
# (Besker, Martini and Bosch 2017, The pricey bill of technical debt: When and by whom will it be paid?)
# (Ampatzoglou et al 2016, The Perception of Technical Debt in the Embedded Systems Domain: An Industrial Case Study)
# (Martini, Besker and Bosch 2016, The Introduction of Technical Debt Tracking in Large Companies)
# (Aaramaa et al 2017, Requirements volatility in software architecture design: An exploratory case study)
# (Martini et al 2015, Investigating Architectural Technical Debt accumulation and refactoring over time: A multiple-case study)
# (Cai el al 2018, Design Rule Spaces: A New Model for Representing and Analyzing Software Architecture)
# (Bogner et al 2019, Assuring the Evolvability of Microservices: Insights into Industry Practices and Challenges)
# (Ludwig and Webber 2017, Compiling Static Software Metrics for Reliability and Maintainability from GitHub Repositories)
# (Curtis et al 2012, Estimating the principal of an applications technical debt)
# (Curtis et al 2012, Estimating the Size, Cost, and Types of Technical Debt)
# (Kumar et al 2018, Exploring multilateral cloud computing security architectural design debt in terms of technical debt)
# (Hanssen et al 2019, Identifying Scalability Debt in Open Systems)
# (Sierra et al 2019, Is Self-Admitted Technical Debt a Good Indicator of Architectural Divergences?)
# (Bogner et al 2018, Limiting technical debt with maintainability assurance: an industry survey on used techniques and differences with service- and microservice-based systems)
# (Andrzej Zalewski 2017, Risk Appetite in Architectural Decision-Making)
# (Damian A. Tamburri 2019, Software Architecture Social Debt: Managing the Incommunicability Factor)

# %% [markdown]
# ## 1.2 List of Authors

# %%
list_of_authors, list_of_uniques_authors = util.list_of_items(df_data=df_sms_extraction, column_name='Authors')
# Out:
# List of all 158 Authors : ['Boris Perez', 'Dario Correal', 'Hernan Astudillo', 'Antonio Martini', 'Erik Sikander', 'Niel Madlani', 'Riccardo Roveda', 'Francesca Arcelli Fontana', 'Ilaria Pigazzini', 'Marco Zanoni', 'Will Snipes', 'Sunil L Karlekar', 'Ran Mo', 'Maleknaz Nayebi', 'Yuanfang Cai', 'Rick Kazman', 'Guenther Ruhe', 'Qiong Feng', 'Chris Carlson', 'Francis Chew', 'Qiong Feng', 'Yuanfang Cai', 'Rick Kazman', 'Di Cui', 'Ting Liu', 'Hongzhou Fang', 'Zengyang Li', 'Peng Liang', 'Paris Avgeriou', 'Nicolas Guelfi', 'Apostolos Ampatzoglou', 'Antonio Martini', 'Jan Bosch', 'Lu Xiao', 'Yuanfang Cai', 'Rick Kazman', 'Ran Mo', 'Qiong Feng', 'Roberto Verdecchia', 'Alexander von Zitzewitz', 'Antonio Martini', 'Jan Bosch', 'Francesca Arcelli Fontana', 'Riccardo Roveda', 'Marco Zanoni', 'Zengyang Li', 'Peng Liang', 'Paris Avgeriou', 'Antonio Martini', 'Jan Bosch', 'Michel Chaudron', 'Antonio Martini', 'Erik Sikander', 'Niel Madlani', 'Antonio Martini', 'Francesca Arcelli Fontana', 'Andrea Biaggi', 'Riccardo Roveda', '', 'Yuanfang Cai and Rick Kazman', 'Rick Kazman', 'Yuanfang Cai', 'Ran Mo', 'Qiong Feng', 'Lu Xiao', 'Serge Haziyev', 'Volodymyr Fedak', 'Andriy Shapochka', 'Antonio Martini', 'Jan Bosch', 'Antonela Tommasel', 'Robert L. Nord', 'Ipek Ozkaya', 'Philippe Kruchten', 'Marco Gonzalez-Rojas', 'Yuanfang Cai and Rick Kazman', 'Peggy Skiada', 'Apostolos Ampatzoglou', 'Elvira-Maria Arvanitou', 'Alexander Chatzigeorgiou', 'Ioannis Stamelos', 'Ulf Eliasson', 'Antonio Martini', 'Robert Kaufmann', 'Sam Odeh', 'Francesca Arcelli Fontana', 'Riccardo Roveda', 'Marco Zanoni', 'Alan MacCormack', 'Daniel J. Sturtevant', 'Darius Sas', 'Paris Avgeriou', 'Francesca Arcelli Fontana', 'Francesca Arcelli Fontana', 'Ilaria Pigazzini', 'Claudia Raibulet', 'Stefano Basciano', 'Diomidis Spinellis and Paris Avgeriou', 'Clemente Izurieta', 'Kali Kimball', 'David Rice', 'Tessa Valentien', 'Terese Besker', 'Antonio Martini', 'Jan Bosch', 'Areti Ampatzoglou', 'Apostolos Ampatzoglou', 'Alexander Chatzigeorgiou', 'Paris Avgeriou', 'Pekka Abrahamsson', 'Antonio Martini', '', 'Antonio Martini', 'Terese Besker', 'Jan Bosch', 'Sanja Aaramaa', 'Sandun Dasanayake Sandun Dasanayake', 'Markku Oivo Markku Oivo', 'Jouni Markkula Jouni Markkula', 'Samuli Saukkonen', 'Antonio Martini', 'Jan Bosch', 'Michel Chaudron', 'Yuanfang Cai', 'Lu Xiao', 'Rick Kazman', 'Ran Mo', 'and Qiong Feng', 'Justus Bogner', 'Jonas Fritzsch', 'Stefan Wagner†', 'Alfred Zimmermann', 'Jeremy Ludwig', 'Steven Xu', 'Frederick Webber', 'Bill Curtis', 'Jay Sappidi', 'and Alexandra Szynkarski', '', 'Bill Curtis', 'Jay Sappidi', 'and Alexandra Szynkarski', '', 'M. Manoj Kumar', 'A. Nandakumar', 'Geir Kjetil Hanssen', 'Gunnar Brataas', 'Antonio Martini', 'G Sierra', 'A Tahmid', 'E Shihab', 'N Tsantalis.', 'Justus Bogner', 'Jonas Fritzsch Jonas Fritzsch', 'Stefan Wagner Stefan Wagner', 'Alfred Zimmermann', 'Andrzej Zalewski', 'Damian A. Tamburri']
#
# List of unique 92 Authors : ['', 'Sandun Dasanayake Sandun Dasanayake', 'Steven Xu', 'Frederick Webber', 'David Rice', 'Alexander Chatzigeorgiou', 'Terese Besker', 'Andrzej Zalewski', 'Guenther Ruhe', 'Sam Odeh', 'Apostolos Ampatzoglou', 'Michel Chaudron', 'Antonio Martini', 'Areti Ampatzoglou', 'Chris Carlson', 'A. Nandakumar', 'Qiong Feng', 'Damian A. Tamburri', 'Yuanfang Cai and Rick Kazman', 'Markku Oivo Markku Oivo', 'G Sierra', 'Alexander von Zitzewitz', 'and Alexandra Szynkarski', 'E Shihab', 'Samuli Saukkonen', 'Tessa Valentien', 'Claudia Raibulet', 'Robert L. Nord', 'Jonas Fritzsch', 'Zengyang Li', 'Stefan Wagner Stefan Wagner', 'Francis Chew', 'Niel Madlani', 'Riccardo Roveda', 'Jan Bosch', 'Robert Kaufmann', 'Justus Bogner', 'Serge Haziyev', 'Geir Kjetil Hanssen', 'Darius Sas', 'Daniel J. Sturtevant', 'Diomidis Spinellis and Paris Avgeriou', 'Sunil L Karlekar', 'Ting Liu', 'Rick Kazman', 'Peng Liang', 'Alan MacCormack', 'Ulf Eliasson', 'Francesca Arcelli Fontana', 'Andriy Shapochka', 'Antonela Tommasel', 'Boris Perez', 'N Tsantalis.', 'Yuanfang Cai', 'Elvira-Maria Arvanitou', 'Di Cui', 'Jonas Fritzsch Jonas Fritzsch', 'Erik Sikander', 'Roberto Verdecchia', 'Jouni Markkula Jouni Markkula', 'A Tahmid', 'M. Manoj Kumar', 'Ran Mo', 'Paris Avgeriou', 'Lu Xiao', 'Pekka Abrahamsson', 'Peggy Skiada', 'Nicolas Guelfi', 'Volodymyr Fedak', 'Kali Kimball', 'Ilaria Pigazzini', 'and Qiong Feng', 'Philippe Kruchten', 'Hongzhou Fang', 'Marco Gonzalez-Rojas', 'Marco Zanoni', 'Ioannis Stamelos', 'Clemente Izurieta', 'Bill Curtis', 'Maleknaz Nayebi', 'Jeremy Ludwig', 'Gunnar Brataas', 'Stefano Basciano', 'Hernan Astudillo', 'Sanja Aaramaa', 'Andrea Biaggi', 'Alfred Zimmermann', 'Ipek Ozkaya', 'Stefan Wagner†', 'Will Snipes', 'Dario Correal', 'Jay Sappidi']

# %% [markdown]
# ## 1.3 List of Key words

# %%
list_of_key_words, list_of_uniques_key_words = util.list_of_items(df_data=df_sms_extraction, column_name='Key words')
# Out:
# List of all 190 Key words : ['Architectural technical debt', 'Software architecture', 'Architectural technical debt management', 'Model-driven architecture', 'Measurement System Software management Refactoring Estimation Technical Debt Modularization Software Architecture', 'architectural smells', 'architectural debt index', 'severity index', 'technical debt', 'Software Architecture', 'Software Maintenance', 'Technical Debt', 'Architecture debt', 'Cost-benefit analysis', 'Longi- tudinal study', 'Refactoring', 'software evolution', 'architecture debt', 'Architectural technical debt', 'modularity metric', 'commit', 'software architecture', 'Management', 'Measurement', 'Design', 'Economics.', 'Software Architecture', 'Software Quality', 'Technical Debt', 'Software Architecture', 'Technical Debt', 'Android', 'Compliance Checking', 'software artchitecture', 'software metrics', 'architectural debt', 'agile software development', 'architectural technical debt', 'effort', 'multiple case study', 'qualitative model', 'sociotechnical phenomena', 'Architectural deb', 'Tool experimentation', 'Architecture assessment', 'Architectural technical debt', 'architectural technical debt identification', 'architecture decision', 'change scenario', 'architectural technical debt', 'agile software development', 'development speed', 'software life-cycle', 'influencing factors', 'qualitative model', 'Grounded Theory', 'Software Management', 'Refactoring', 'Estimation', 'Technical Debt', 'Modularization', 'Software Architecture.', 'Not available', 'Software architecture health monitor', 'Computer architecture', 'Software engineering', 'Business', 'History', 'Sonar detection', 'Microprocessors', 'Architecture Technical Debt', 'Prioritization Aspects', 'Feature Prioritization', 'Refactoring Prioritization', 'Information Need', 'Measurement', 'Social networking (online)', 'Computer architecture', 'Software architecture', 'Software systems', 'Software design', 'technical debt', 'software architecture', 'software economics', 'cost of rework', 'total cost of ownership', 'Software Architecture', 'Software Quality', 'Software Maintenance', 'coupling', 'cohesion', 'modularity', 'technical debt', 'Software', 'Visualization', 'Computer architecture', 'Stakeholders', 'Context', 'Automotive engineering', 'Complex systems', 'Technical Debt Indexes', 'Architectural Debt', 'Software Quality Analysis Tools', 'Technical Debt', 'Software Architeture', 'Software', 'architectural smells', 'technical debt', 'architectural technical debt', 'cyclic dependencies', 'architectural smells evolution', 'Architectural smells', 'PageRank', 'Criticality', 'Architectural debt', 'Ar- chitecture erosion', 'Prioritization', 'Unix', 'Software Architecture', 'Software Evolution', 'Architecture Design Decisions', 'Operating Systems.', 'quality assurance', 'software quality', 'technical debt', 'Technical Debt', 'Wasted time', 'Development Cost', 'Software Development', 'Empirical Study', 'Survey', 'Qualitative data', 'Quantitative data', 'technical debt', 'embedded systems', 'industry case study', 'Technical Debt', 'change management', 'software process improvement', 'survey', 'multiple case-study', 'Requirement management', 'software architecture', 'Architectural Technical Debt Software management Software architecture Agile software development Software life-cycle Qualitative model', 'Software architecture', 'reverse-engineering', 'defect prediction', 'technical debt', 'code smells', 'bug localization', 'Microservices', 'interviews', 'industry', 'evolvability', 'assurance', 'softwareproductquality', 'technicaldebt', 'reliability', 'maintainability', 'architecture', 'metrics', 'static code analysis', 'IEEE Newspaper', 'software metrics', 'software structural quality', 'technical debt', 'static analysis', 'benchmarking', 'Multilateral cloud security architecture Design smells Technical debt Design debt Cloud computing security Design refactoring', 'agile development', 'scalability requirements' ...
#
# List of unique 151 Key words : ['evolvability', 'architecture decision', 'architectural technical debt', 'quality assurance', 'Architectural Debt', 'Software Quality Analysis Tools', 'modularity metric', 'agile software development', 'Visualization', 'multiple case-study', 'Software architecture health monitor', 'defect prediction', 'open banking', 'Grounded Theory', 'Model-driven architecture', 'Software systems', 'reverse-engineering', 'Software design', 'social debt in software architecting', 'PageRank', 'risk', 'IEEE Newspaper', 'reliability', 'Automotive engineering', 'software structural quality', 'Compliance Checking', 'Software', 'effort', 'Technical Debt Indexes', 'social debt cost estimation', 'maintainability', 'Prioritization', 'scalability requirements', 'software metrics', 'Longi- tudinal study', 'Architecture Design Decisions', 'Architectural technical debt management', 'Unix', 'Architectural deb', 'Feature Prioritization', 'total cost of ownership', 'Criticality', 'Business', 'service- based systems', 'bug localization', 'architecture', 'Empirical Study', 'software process improvement', 'metrics', 'Architecture assessment', 'architectural technical debt identification', 'severity index', 'Information Need', 'development speed', 'History', 'Software Evolution', 'Development Cost', 'microservice-based systems', 'Sonar detection', 'Software engineering', 'Cost-benefit analysis', 'Software Quality', 'Terms—Social debt', 'Architectural smells', 'Qualitative data', 'Prioritization Aspects', 'Refactoring', 'Architecture Recovery', 'softwareproductquality', 'Architecture debt', 'architectural debt', 'Maintainability', 'cyclic dependencies', 'software life-cycle', 'modularity', 'Measurement', 'Android', 'coupling', 'Computer architecture', 'Wasted time', 'Technical Debt', 'technical debt.', 'Economics.', 'Measurement System Software management Refactoring Estimation Technical Debt Modularization Software Architecture', 'software quality', 'Software architecture', 'static analysis', 'sociotechnical phenomena', 'Software Re- Engineering', 'Refactoring Prioritization', 'Survey', 'change management', 'software architecture', 'architecture debt', 'Modularization', 'Architecture Technical Debt', 'Architectural debt', 'code smells', 'benchmarking', 'Estimation', 'architectural smells', 'cost of rework', 'technical debt', 'Architectural technical debt', 'assurance', 'agile development', 'Context', 'Self-Admitted Technical Debt', 'Complex systems', 'software economics', 'architecture decision-making', 'Multilateral cloud security architecture Design smells Technical debt Design debt Cloud computing security Design refactoring', 'influencing factors', 'Operating Systems.', 'Ar- chitecture erosion', 'Design', 'risk appetite', 'Software Management', 'interviews', 'cohesion', 'survey', 'software artchitecture', 'embedded systems', 'software quality control', 'Requirement management', 'Software Architecture', 'Microservices', 'Architectural Technical Debt Software management Software architecture Agile software development Software life-cycle Qualitative model', 'software evolution', 'Software Maintenance', 'Tool experimentation', 'Software Architecture.', 'industry case study', 'Stakeholders', 'Software Development', 'Quantitative data', 'static code analysis', 'Not available', 'architectural debt index', 'Management', 'change scenario', 'multiple case study', 'scalability triage', 'Microprocessors', 'Software Architeture', 'qualitative model', 'Social networking (online)', 'technicaldebt', 'architectural smells evolution', 'industry', 'commit']

# %% [markdown]
# ## 1.4 List of Venues

# %%
list_of_venues = []
for item in list(df_sms_extraction['Name of Venue']): 
    item = ' '.join(item.split())
    list_of_venues.append(item)
list_of_venues.sort()
for each in list_of_venues:
    print(each)
# Out:
# Asia Pacific Software Engineering Conference
# Conference on Software Achitecture
# Conference on Software Architecture and European Conference on Software Architecture
# EE Transactions on Software Engineering
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# European Conference on Software Architecture
# European Conference on Software Architecture
# IEEE Software
# Information and Software Technology Journal
# International Conference on Automated Software Engineering (ASE)
# International Conference on Mobile Software Engineering and Systems
# International Conference on Software Architecture Companion (ICSA-C)
# International Conference on Software Architecture Workshops (ICSAW)
# International Conference on Software Engineering
# International Conference on Software Engineering
# International Conference on Software Engineering
# International Conference on Software Engineering Companion
# International Conference on Software Engineering: Software Engineering in Practice.
# International Conference on Software Maintenance and Evolution
# International Conference on Software Maintenance and Evolution (ICSME)
# International Conference on Software Maintenance and Evolution (ICSME)
# International Conference on Software and System Process
# International Conference on Systems, Man, and Cybernetics (SMC)
# International Conference on Technical Debt
# International Conference on Technical Debt
# International Conference on Technical Debt (TechDebt)
# International Conference on Technical Debt (TechDebt)
# International Conference on Technical Debt (TechDebt)
# International Conference on Technical Debt (TechDebt)
# International Workshop on Bringing Architectural Design Thinking
# International Workshop on Managing Technical Debt
# International Workshop on Managing Technical Debt (MTD)
# International Workshop on Managing Technical Debt (MTD)
# International Workshop on Managing Technical Debt (MTD)
# Jornal Information and Software Technology
# Journal of Software: Evolution and Process
# Journal of Systems and Software
# SANER
# Springer Nature Singapore
# Symposium on Applied Computing
# TRANSACTIONS ON COMPUTATIONAL SOCIAL SYSTEMS
# international ACM Sigsoft conference on Quality of software architectures

# %% [markdown]
# ## 1.5 The papers below have to be revised:

# %%
df_sms_extraction[df_sms_extraction["Kind of reasearch"].isnull()][['Paper Id', 'Citation', 'Title']]
# Out:
#     Paper Id                Citation  \
# 20        20           Tommasel 2019
# 36        24          Cai el al 2018
# 37        77       Bogner et al 2019
# 38        78  Ludwig and Webber 2017
# 45        97   Andrzej Zalewski 2017
#
#                                                 Title
# 20  Applying Social Network Analysis Techniques to...
# 36  Design Rule Spaces: A New Model for Representi...
# 37  Assuring the Evolvability of Microservices: In...
# 38  Compiling Static Software Metrics for Reliabil...
# 45     Risk Appetite in Architectural Decision-Making

# %%
df_sms_extraction[df_sms_extraction["Techniques, approach, methods and tools"].isnull()][['Paper Id','Citation', 'Title']]
# Out:
#     Paper Id                 Citation  \
# 20        20            Tommasel 2019
# 21        33         Nord et al. 2012
# 45        97    Andrzej Zalewski 2017
# 46        40  Damian A. Tamburri 2019
#
#                                                 Title
# 20  Applying Social Network Analysis Techniques to...
# 21  In Search of a Metric for Managing Architectur...
# 45     Risk Appetite in Architectural Decision-Making
# 46  Software Architecture Social Debt: Managing th...

# %%
print(" List of papers to review Scientific Rigor: {}".format(len(df_sms_extraction[df_sms_extraction["Scientific Rigor"].isnull()][['Paper Id','Citation', 'Title']])) )
# Out:
#  List of papers to review Scientific Rigor: 38

# %%
df_sms_extraction[df_sms_extraction["Scientific Rigor"].isnull()][['Paper Id','Citation', 'Title']]
# Out:
#     Paper Id                        Citation  \
# 0          1               Perez et al. 2019
# 4          5              Nayebi et al. 2019
# 5          7                Feng et al. 2019
# 6          9                  Li et al. 2014
# 7         10             Martini et al. 2016
# 8         13                Xiao et al. 2016
# 9         14                 Verdecchia 2018
# 10        15           Zitzweitz et al. 2019
# 11        16          Martini and Bosch 2017
# 12        17             Fontana et al. 2016
# 13        21                  Li et al. 2015
# 14        22             Martini et al. 2014
# 15        27             Martini et al. 2016
# 16        30             Martini et al. 2018
# 17        38             Cai and Kazman 2016
# 18        48              Kazman et al. 2015
# 19        47          Martini and Bosch 2015
# 20        20                   Tommasel 2019
# 21        33                Nord et al. 2012
# 22        26             Cai and Kazman 2019
# 28        52             Fontana et al. 2019
# 29        63     Spinellis and Avgeriou 2019
# 31        69  Besker, Martini and Bosch 2017
# 32        67          Ampatzoglou et al 2016
# 33        66  Martini, Besker and Bosch 2016
# 34        96              Aaramaa et al 2017
# 35        35              Martini et al 2015
# 36        24                  Cai el al 2018
# 37        77               Bogner et al 2019
# 38        78          Ludwig and Webber 2017
# 39        81               Curtis et al 2012
# 40        82               Curtis et al 2012
# 41        85                Kumar et al 2018
# 42        88              Hanssen et al 2019
# 43        90               Sierra et al 2019
# 44        91               Bogner et al 2018
# 45        97           Andrzej Zalewski 2017
# 46        40         Damian A. Tamburri 2019
#
#                                                 Title
# 0   A Proposed Model-driven Approach to Manage Arc...
# 4   A Longitudinal Study of Identifying and Paying...
# 5   Active Hotspot: An Issue-Oriented Model to Mon...
# 6   An  Empirical Investigation of Modularity Metr...
# 7   An Empirically Developed Method to Aid Decisio...
# 8     Identifying and Quantifying Architectural Debt
# 9   Identifying Architectural Technical Debt in An...
# 10  Mitigating Technical and Architectural Debt wi...
# 11  On the interest of architectural technical deb...
# 12  Tool support for evaluating architectural debt...
# 13  Architectural Technical Debt Identification ba...
# 14  Architecture Technical Debt: Understanding Cau...
# 15  Estimating and Quantifying the Benefits of Ref...
# 16  Identifying and Prioritizing Architectural Deb...
# 17               Software Architecture Health Monitor
# 18  A Case Study in Locating the Architectural Roo...
# 19  Towards Prioritizing Architecture Technical De...
# 20  Applying Social Network Analysis Techniques to...
# 21  In Search of a Metric for Managing Architectur...
# 22  DV8: Automated Architecture Analysis Tool Suites
# 28   PageRank and criticality of architectural smells
# 29  Evolution of the Unix System Architecture: An ...
# 31  The pricey bill of technical debt: When and by...
# 32  The Perception of Technical Debt in the Embedd...
# 33  The Introduction of Technical Debt Tracking in...
# 34  Requirements volatility in software architectu...
# 35  Investigating Architectural Technical Debt acc...
# 36  Design Rule Spaces: A New Model for Representi...
# 37  Assuring the Evolvability of Microservices: In...
# 38  Compiling Static Software Metrics for Reliabil...
# 39  Estimating the principal of an applications te...
# 40  Estimating the Size, Cost, and Types of Techni...
# 41  Exploring multilateral cloud computing securit...
# 42       Identifying Scalability Debt in Open Systems
# 43  Is Self-Admitted Technical Debt a Good Indicat...
# 44  Limiting technical debt with maintainability a...
# 45     Risk Appetite in Architectural Decision-Making
# 46  Software Architecture Social Debt: Managing th...

# %% [markdown]
# ## 1.6 Basic statistic

# %%
publication_per_year = dict(df_sms_extraction['Publication Year'].value_counts())
util.show_bar_plot_complete(publication_per_year, 'Publication per year', x_label='Ano', y_label='Quantidade')

venue_per_type = dict(df_sms_extraction['Venue Type'].value_counts())
util.show_bar_plot_complete(venue_per_type, 'Venue per type', x_label='Tipo', y_label='Quantidade')

number_of_page_grouped = dict(df_sms_extraction['Number of Pages'].value_counts())
util.show_bar_plot_complete(number_of_page_grouped, 'Count of number of pages', x_label='Páginas', y_label='Frequencia')

# %%
df_sms_extraction[df_sms_extraction['Paper Id'] == 69]
# Out:
#     Paper Id                        Citation Google Scholar  \
# 31        69  Besker, Martini and Bosch 2017             21
#
#                                       Authors  \
# 31  Terese Besker, Antonio Martini, Jan Bosch
#
#                                                 Title  Publication Year  \
# 31  The pricey bill of technical debt: When and by...              2017
#
#                                              Abstract  Venue Type  \
# 31  Software companies need to support continuous ...  Conference
#
#                                                 Venue  \
# 31  International Conference on Software Maintenan...
#
#                                         Name of Venue  ...  \
# 31  International Conference on Software Maintenan...  ...
#
#                   Q4 (Calculate the cost)
#  yes - how?  \
# 31  36% of effort in Software development cycle is...
#
#                                    Extra (Conclusion)  \
# 31  This is the first study surveying the estimate...
#
#                                 Extra2 (Related work)  \
# 31  Empirical survey-based studies on TD \n- Ernst...
#
#    Extra 3 (Important work) Strong Aspects Weak Aspects Scientific Rigor  \
# 31                      NaN            NaN          NaN              NaN
#
#    Paper relevance Limitations Future Works
# 31             NaN         NaN          NaN
#
# [1 rows x 29 columns]

# %% [markdown]
# # 2 Special analyses

# %%
def macro_wordcloud_content_analysis(path_file, name):
    util.generateWordcloudFromTextFile(path_file, name)
    util.contentAnalysisFromTextFile(path_file)

# %% [markdown]
# ## 2.1 We are creating a text file appended for each analyzed column.

# %%
path_abstracts_file = '../dataset/abstracts.txt'
path_goals_file = '../dataset/goals.txt'
path_conclusions_file = '../dataset/conclusions.txt'
path_futures_file = '../dataset/futures.txt'

column_names_df_sms_extraction = df_sms_extraction.columns
abstract_column = column_names_df_sms_extraction[6]
goal_column = column_names_df_sms_extraction[13]
conclusions_column = column_names_df_sms_extraction[20]
future_column = column_names_df_sms_extraction[28]

util.appendContentsInTextFile(path_abstracts_file, df_sms_extraction[abstract_column])
util.appendContentsInTextFile(path_goals_file, df_sms_extraction[goal_column])
util.appendContentsInTextFile(path_conclusions_file, df_sms_extraction[conclusions_column])
util.appendContentsInTextFile(path_futures_file, df_sms_extraction[future_column])
# Out:
# The file ../dataset/abstracts.txt was created with sucess!
# The ../dataset/abstracts.txt has appended all abstract content with sucess!
# The file ../dataset/goals.txt was created with sucess!
# The ../dataset/goals.txt has appended all abstract content with sucess!
# The file ../dataset/conclusions.txt was created with sucess!
# The ../dataset/conclusions.txt has appended all abstract content with sucess!
# The file ../dataset/futures.txt was created with sucess!
# The ../dataset/futures.txt has appended all abstract content with sucess!

# %%
# Allows NLP (Natural Language Process) for each content in dataframe
util.loadSupportTokenization()
# Out:
# Starting download punkt to suport tokeninzing...
# Download concluído.
# Unzip concluído.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/armandosoaressousa/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## 2.2 Generate the wordcloud of abstracts content and content analysis

# %%
macro_wordcloud_content_analysis(path_abstracts_file, 'abstracts')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 455)
# ('and', 291)
# ('debt', 140)
# ('that', 116)
# ('architectural', 102)
# ('technical', 94)
# ('software', 93)
# ('this', 74)
# ('for', 69)
# ('architecture', 65)
# ('are', 57)
# ('system', 49)
# ('can', 47)
# ('with', 42)
# ('study', 41)
# ('design', 38)
# ('has', 34)
# ('development', 33)
# ('from', 33)
# ('these', 29)
# ('systems', 29)
# ('maintenance', 28)
# ('have', 28)
# ('their', 27)
# ('project', 26)
# ('code', 26)
# ('which', 26)
# ('results', 26)
# ('been', 24)
# ('not', 24)
# ('quality', 24)
# ('paper', 24)
# ('how', 24)
# ('time', 23)
# ('case', 23)
# ('atd', 21)
# ('refactoring', 21)
# ('large', 20)
# ('interest', 20)
# ('its', 19)
# ('such', 19)
# ('different', 19)
# ('smells', 19)
# ('source', 19)
# ('analysis', 19)
# ('over', 18)
# ('decisions', 17)
# ('architects', 17)
# ('files', 17)
# ('evolution', 17)
# ('approach', 16)
# ('identified', 16)
# ('issues', 16)
# ('metrics', 16)
# ('they', 16)
# ('tools', 16)
# ('but', 15)
# ('impact', 15)
# ('was', 15)
# ('conducted', 15)
# ('costs', 15)
# ('flaws', 15)
# ('companies', 15)
# ('most', 15)
# ('however', 14)
# ('model', 14)
# ('other', 14)
# ('research', 14)
# ('identify', 14)
# ('into', 14)
# ('more', 14)
# ('using', 14)
# ('both', 14)
# ('practitioners', 14)
# ('components', 13)
# ('show', 13)
# ('based', 13)
# ('our', 13)
# ('requirements', 13)
# ('used', 12)
# ('business', 12)
# ('modularity', 12)
# ('method', 12)
# ('maintainability', 12)
# ('important', 12)
# Número total de palavras é 8076
# Número de palavras únicas é 1652

# %% [markdown]
# ## 2.3 Generate the wordcloud of goals content and content analysis

# %%
macro_wordcloud_content_analysis(path_goals_file, 'goals')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 524)
# ('and', 248)
# ('that', 74)
# ('for', 74)
# ('this', 71)
# ('software', 71)
# ('atd', 68)
# ('debt', 67)
# ('architectural', 65)
# ('are', 59)
# ('architecture', 59)
# ('how', 55)
# ('with', 55)
# ('can', 46)
# ('study', 43)
# ('what', 41)
# ('technical', 36)
# ('have', 35)
# ('system', 34)
# ('design', 34)
# ('their', 32)
# ('our', 31)
# ('from', 31)
# ('paper', 30)
# ('project', 29)
# ('interest', 28)
# ('these', 28)
# ('which', 28)
# ('files', 27)
# ('refactoring', 26)
# ('such', 25)
# ('development', 24)
# ('approach', 23)
# ('code', 23)
# ('maintenance', 22)
# ('smells', 22)
# ('quality', 22)
# ('research', 22)
# ('tools', 22)
# ('identify', 21)
# ('debts', 21)
# ('architects', 20)
# ('questions', 20)
# ('time', 20)
# ('not', 20)
# ('case', 19)
# ('index', 19)
# ('based', 19)
# ('each', 19)
# ('different', 19)
# ('impact', 18)
# ('using', 18)
# ('evolution', 18)
# ('source', 17)
# ('analysis', 17)
# ('more', 16)
# ('large', 16)
# ('they', 16)
# ('following', 15)
# ('issues', 15)
# ('identified', 15)
# ('accumulation', 15)
# ('systems', 15)
# ('were', 15)
# ('other', 14)
# ('smell', 14)
# ('two', 14)
# ('over', 14)
# ('between', 14)
# ('model', 13)
# ('its', 13)
# ('main', 13)
# ('goal', 13)
# ('groups', 13)
# ('related', 13)
# ('process', 13)
# ('decisions', 12)
# ('focus', 12)
# ('also', 12)
# ('metrics', 12)
# ('level', 12)
# ('file', 12)
# Número total de palavras é 7851
# Número de palavras únicas é 1509

# %% [markdown]
# ## 2.4 Generate the wordcloud of conclusions content and content analysis

# %%
macro_wordcloud_content_analysis(path_conclusions_file, 'conclusions')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 899)
# ('and', 434)
# ('that', 168)
# ('for', 126)
# ('this', 119)
# ('with', 116)
# ('debt', 90)
# ('are', 88)
# ('can', 85)
# ('architectural', 80)
# ('atd', 78)
# ('architecture', 69)
# ('software', 61)
# ('study', 55)
# ('different', 52)
# ('have', 49)
# ('also', 48)
# ('such', 48)
# ('which', 47)
# ('more', 46)
# ('system', 43)
# ('refactoring', 42)
# ('their', 42)
# ('not', 41)
# ('our', 40)
# ('case', 38)
# ('quality', 36)
# ('project', 35)
# ('how', 35)
# ('interest', 34)
# ('these', 33)
# ('paper', 33)
# ('metrics', 33)
# ('technical', 32)
# ('from', 32)
# ('time', 32)
# ('based', 31)
# ('code', 31)
# ('other', 30)
# ('they', 30)
# ('files', 30)
# ('used', 29)
# ('projects', 29)
# ('development', 29)
# ('was', 27)
# ('approach', 26)
# ('could', 26)
# ('most', 26)
# ('impact', 25)
# ('decisions', 25)
# ('smells', 25)
# ('tools', 25)
# ('design', 24)
# ('process', 24)
# ('research', 24)
# ('work', 24)
# ('were', 23)
# ('tool', 23)
# ('results', 23)
# ('identify', 23)
# ('index', 23)
# ('each', 23)
# ('would', 23)
# ('data', 23)
# ('information', 22)
# ('but', 22)
# ('future', 22)
# ('systems', 22)
# ('maintenance', 22)
# ('new', 22)
# ('issues', 22)
# ('using', 21)
# ('practitioners', 21)
# ('costs', 21)
# ('plan', 20)
# ('value', 20)
# ('has', 20)
# ('evolution', 20)
# ('them', 20)
# ('large', 20)
# ('first', 19)
# ('provide', 19)
# ('between', 19)
# ('analysis', 19)
# Número total de palavras é 12642
# Número de palavras únicas é 2152

# %% [markdown]
# ## 2.5 Generate the wordcloud of future work content and content analysis

# %%
macro_wordcloud_content_analysis(path_futures_file, 'future_works')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 31)
# ('and', 18)
# ('future', 8)
# ('architectural', 7)
# ('smells', 7)
# ('that', 7)
# ('would', 6)
# ('code', 6)
# ('work', 5)
# ('plan', 5)
# ('for', 5)
# ('with', 5)
# ('different', 4)
# ('impact', 4)
# ('which', 4)
# ('issues', 4)
# ('are', 4)
# ('can', 4)
# ('debt', 4)
# ('associated', 4)
# ('also', 3)
# ('like', 3)
# ('could', 3)
# ('quality', 3)
# ('our', 3)
# ('what', 3)
# ('investigate', 3)
# ('they', 3)
# ('see', 3)
# ('architecture', 3)
# ('tdi', 3)
# ('from', 3)
# ('such', 2)
# ('this', 2)
# ('according', 2)
# ('study', 2)
# ('process', 2)
# ('extend', 2)
# ('analysis', 2)
# ('other', 2)
# ('atd', 2)
# ('measures', 2)
# ('stakeholders', 2)
# ('violations', 2)
# ('whatever', 2)
# ('finally', 2)
# ('changes', 2)
# ('relevance', 2)
# ('their', 2)
# ('new', 2)
# ('focus', 2)
# ('metrics', 2)
# ('number', 2)
# ('provides', 2)
# ('studies', 2)
# ('costs', 2)
# ('maintenance', 2)
# ('methods', 2)
# ('nannanthe', 1)
# ('authors', 1)
# ('detect', 1)
# ('categories', 1)
# ('attributes', 1)
# ('performance', 1)
# ('security', 1)
# ('direction', 1)
# ('identify', 1)
# ('compute', 1)
# ('adi', 1)
# ('index', 1)
# ('profiles', 1)
# ('specific', 1)
# ('issue', 1)
# ('removal', 1)
# ('determine', 1)
# ('most', 1)
# ('costly', 1)
# ('remove', 1)
# ('generally', 1)
# ('wider', 1)
# ('range', 1)
# ('project', 1)
# ('domains', 1)
# ('continue', 1)
# ('research', 1)
# ('items', 1)
# ('found', 1)
# ('combined', 1)
# ('together', 1)
# Número total de palavras é 495
# Número de palavras únicas é 233
