# %%
import pandas as pd
import utilities as util

# %%
# Import papers spreadsheet to dataset
df_sms_extraction = pd.read_excel('../dataset/Extraction_form.xlsx')
df_sms_extraction.head(3)
# Out:
#    Paper Id            Citation Google Scholar  \
# 0         1   Perez et al. 2019              1
# 1         2  Martini et al 2017             13
# 2         3  Roveda et al. 2018             13
#
#                                              Authors  \
# 0  Boris Pe ́rez, Dar ́ıo Correal \n, Herna ́n As...
# 1       Antonio Martini, Erik Sikander, Niel Madlani
# 2  Riccardo Roveda, Francesca Arcelli Fontana, Il...
#
#                                                Title  Publication Year  \
# 0  A Proposed Model-driven Approach to Manage Arc...            2019.0
# 1  A semi-automated framework for the identificat...            2017.0
# 2                Towards an Architectural Debt Index            2018.0
#
#                                             Abstract  Venue Type  \
# 0  Architectural Technical Debt (ATD) is a metaph...         NaN
# 1  Context: Research and industry’s attention has...     Journal
# 2  Different indexes have been proposed to evalua...  Conference
#
#                                                Venue  \
# 0  2019 IEEE/ACM International Conference on Tech...
# 1         Jornal Information and Software Technology
# 2  Euromicro Conference on Software Engineering a...
#
#                                             Field  ...  \
# 0              System Engineering, Technical Debt  ...
# 1                              Software Technolog  ...
# 2  Software Engineering and Advanced Applications  ...
#
#                  Q4 (Calculate the cost)
#  yes - how?  \
# 0                                                NaN
# 1  According Measurement System and formula propo...
# 2                                                NaN
#
#                                   Extra (Conclusion)  \
# 0  We have proposed a model-driven approach for m...
# 1  Companies need to develop systems that are sus...
# 2  In this paper a new index oriented to the eval...
#
#                                Extra2 (Related work) Extra 3 (Important work)  \
# 0  Verdecchia in [16] proposed a technique focuse...                      NaN
# 1  [3] P. Kruchten, R.L. Nord, I. Ozkaya, Technic...                      NaN
# 2  Different quality or technical debt indexes ha...                      NaN
#
#   Strong Aspects Weak Aspects  \
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
#
#                                     Scientific Rigor  \
# 0                                                NaN
# 1  This paper used quantitative and qualitative r...
# 2  The authors cited good references, tools, and ...
#
#                                      Paper relevance  \
# 0                                                NaN
# 1  The paper provides a way to identify and estim...
# 2  The authors defined a set of formulas to repre...
#
#                                          Limitations  \
# 0                                                NaN
# 1  To estimate the effort to fix the ATD is neces...
# 2  The data validation should be performed in a r...
#
#                                         Future Works
# 0                                                NaN
# 1                                                NaN
# 2  The authors would also like to detect differen...
#
# [3 rows x 28 columns]

# %%
df_sms_extraction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 28 columns):
# Paper Id                                   48 non-null int64
# Citation                                   46 non-null object
# Google Scholar                             37 non-null object
# Authors                                    46 non-null object
# Title                                      48 non-null object
# Publication Year                           47 non-null float64
# Abstract                                   47 non-null object
# Venue Type                                 4 non-null object
# Venue                                      47 non-null object
# Field                                      46 non-null object
# Key words                                  43 non-null object
# Number of Pages                            4 non-null float64
# Main aim (Goal)                            47 non-null object
# Techniques, approach, methods and tools    42 non-null object
# Kind of reasearch                          41 non-null object
# Q1 (Measure) yes - what?                  32 non-null object
# Q2 (Monitoring) yes - how?                19 non-null object
# Q3 (Techniques and Tools) yes - what?     31 non-null object
# Q4 (Calculate the cost) yes - how?        19 non-null object
# Extra (Conclusion)                         46 non-null object
# Extra2 (Related work)                      30 non-null object
# Extra 3 (Important work)                   4 non-null object
# Strong Aspects                             1 non-null object
# Weak Aspects                               1 non-null object
# Scientific Rigor                           3 non-null object
# Paper relevance                            3 non-null object
# Limitations                                3 non-null object
# Future Works                               2 non-null object
# dtypes: float64(2), int64(1), object(25)
# memory usage: 10.6+ KB

# %%
path_abstracts_file = '../dataset/abstracts.txt'
path_conclusions_file = '../dataset/conclusions.txt'
path_futures_file = '../dataset/futures.txt'

# %%
column_names_df_sms_extraction = df_sms_extraction.columns
abstract_column = column_names_df_sms_extraction[6]
conclusions_column = column_names_df_sms_extraction[19]
future_column = column_names_df_sms_extraction[27]

# %%
util.appendContentsInTextFile(path_abstracts_file, df_sms_extraction[abstract_column])
util.appendContentsInTextFile(path_conclusions_file, df_sms_extraction[conclusions_column])
util.appendContentsInTextFile(path_futures_file, df_sms_extraction[future_column])
# Out:
# The file ../dataset/abstracts.txt was created with sucess!
# The ../dataset/abstracts.txt has appended all abstract content with sucess!
# The file ../dataset/conclusions.txt was created with sucess!
# The ../dataset/conclusions.txt has appended all abstract content with sucess!
# The file ../dataset/futures.txt was created with sucess!
# The ../dataset/futures.txt has appended all abstract content with sucess!

# %%
# Allows NLP (Natural Language Process) for each content in dataframe
util.loadSupportTokenization()
# Out:
# Starting download punkt to suport tokeninzing...
# Download concluído.
# Unzip concluído.
# [nltk_data] Error loading punkt: HTTP Error 503: Backend is unhealthy

# %%
# Generate the wordcloud of abstracts content
util.generateWordcloudFromTextFile(path_abstracts_file, 'abstracts')

# %%
# Performing the content analysis of abstract text file
util.contentAnalysisFromTextFile(path_abstracts_file)
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 455)
# ('and', 291)
# ('debt', 140)
# ('that', 116)
# ('architectural', 102)
# ('technical', 94)
# ('software', 93)
# ('this', 74)
# ('for', 69)
# ('architecture', 65)
# ('are', 57)
# ('system', 49)
# ('can', 47)
# ('with', 42)
# ('study', 41)
# ('design', 38)
# ('has', 34)
# ('development', 33)
# ('from', 33)
# ('these', 29)
# ('systems', 29)
# ('maintenance', 28)
# ('have', 28)
# ('their', 27)
# ('project', 26)
# ('code', 26)
# ('which', 26)
# ('results', 26)
# ('been', 24)
# ('not', 24)
# ('quality', 24)
# ('paper', 24)
# ('how', 24)
# ('time', 23)
# ('case', 23)
# ('atd', 21)
# ('refactoring', 21)
# ('large', 20)
# ('interest', 20)
# ('its', 19)
# ('such', 19)
# ('different', 19)
# ('smells', 19)
# ('source', 19)
# ('analysis', 19)
# ('over', 18)
# ('decisions', 17)
# ('architects', 17)
# ('files', 17)
# ('evolution', 17)
# ('approach', 16)
# ('identified', 16)
# ('issues', 16)
# ('metrics', 16)
# ('they', 16)
# ('tools', 16)
# ('but', 15)
# ('impact', 15)
# ('was', 15)
# ('conducted', 15)
# ('costs', 15)
# ('flaws', 15)
# ('companies', 15)
# ('most', 15)
# ('however', 14)
# ('model', 14)
# ('other', 14)
# ('research', 14)
# ('identify', 14)
# ('into', 14)
# ('more', 14)
# ('using', 14)
# ('both', 14)
# ('practitioners', 14)
# ('components', 13)
# ('show', 13)
# ('based', 13)
# ('our', 13)
# ('requirements', 13)
# ('used', 12)
# ('business', 12)
# ('modularity', 12)
# ('method', 12)
# ('maintainability', 12)
# ('important', 12)
# Número total de palavras é 8076
# Número de palavras únicas é 1652

# %%
# Generate the wordcloud of conclusions content 
util.generateWordcloudFromTextFile(path_conclusions_file, 'conclusions')

# %%
# Performing the content analysis of conclusions text file
util.contentAnalysisFromTextFile(path_conclusions_file)
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 899)
# ('and', 434)
# ('that', 168)
# ('for', 126)
# ('this', 119)
# ('with', 116)
# ('debt', 90)
# ('are', 88)
# ('can', 85)
# ('architectural', 80)
# ('atd', 78)
# ('architecture', 69)
# ('software', 61)
# ('study', 55)
# ('different', 52)
# ('have', 49)
# ('also', 48)
# ('such', 48)
# ('which', 47)
# ('more', 46)
# ('system', 43)
# ('refactoring', 42)
# ('their', 42)
# ('not', 41)
# ('our', 40)
# ('case', 38)
# ('quality', 36)
# ('project', 35)
# ('how', 35)
# ('interest', 34)
# ('these', 33)
# ('paper', 33)
# ('metrics', 33)
# ('technical', 32)
# ('from', 32)
# ('time', 32)
# ('based', 31)
# ('code', 31)
# ('other', 30)
# ('they', 30)
# ('files', 30)
# ('used', 29)
# ('projects', 29)
# ('development', 29)
# ('was', 27)
# ('approach', 26)
# ('could', 26)
# ('most', 26)
# ('impact', 25)
# ('decisions', 25)
# ('smells', 25)
# ('tools', 25)
# ('design', 24)
# ('process', 24)
# ('research', 24)
# ('work', 24)
# ('were', 23)
# ('tool', 23)
# ('results', 23)
# ('identify', 23)
# ('index', 23)
# ('each', 23)
# ('would', 23)
# ('data', 23)
# ('information', 22)
# ('but', 22)
# ('future', 22)
# ('systems', 22)
# ('maintenance', 22)
# ('new', 22)
# ('issues', 22)
# ('using', 21)
# ('practitioners', 21)
# ('costs', 21)
# ('plan', 20)
# ('value', 20)
# ('has', 20)
# ('evolution', 20)
# ('them', 20)
# ('large', 20)
# ('first', 19)
# ('provide', 19)
# ('between', 19)
# ('analysis', 19)
# Número total de palavras é 12641
# Número de palavras únicas é 2151

# %%
# Generate the wordcloud of future work content
util.generateWordcloudFromTextFile(path_futures_file, 'future_works')

# %%
# Performing the content analysis of future works text file
util.contentAnalysisFromTextFile(path_futures_file)
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('and', 4)
# ('different', 3)
# ('the', 3)
# ('could', 2)
# ('impact', 2)
# ('quality', 2)
# ('this', 2)
# ('nannanthe', 1)
# ('authors', 1)
# ('would', 1)
# ('also', 1)
# ('like', 1)
# ('detect', 1)
# ('categories', 1)
# ('architectural', 1)
# ('smells', 1)
# ('that', 1)
# ('attributes', 1)
# ('such', 1)
# ('performance', 1)
# ('security', 1)
# ('direction', 1)
# ('identify', 1)
# ('compute', 1)
# ('adi', 1)
# ('index', 1)
# ('profiles', 1)
# ('according', 1)
# ('specific', 1)
# ('future', 1)
# ('work', 1)
# ('plan', 1)
# ('study', 1)
# ('process', 1)
# ('issue', 1)
# ('removal', 1)
# ('determine', 1)
# ('which', 1)
# ('issues', 1)
# ('are', 1)
# ('most', 1)
# ('costly', 1)
# ('remove', 1)
# ('generally', 1)
# ('extend', 1)
# ('analysis', 1)
# ('wider', 1)
# ('range', 1)
# ('project', 1)
# ('domains', 1)
# Número total de palavras é 78
# Número de palavras únicas é 57
