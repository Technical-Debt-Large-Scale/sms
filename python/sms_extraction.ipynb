# %%
import pandas as pd
import utilities as util
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Dataset

# %%
# Import papers spreadsheet to dataset
df_sms_extraction = pd.read_excel('../dataset/Extraction_form.xlsx')
df_sms_extraction.head(1)
# Out:
#    Paper Id           Citation Google Scholar  \
# 0         1  Perez et al. 2019              4
#
#                                         Authors  \
# 0  Boris Perez, Dario Correal, Hernan Astudillo
#
#                                                Title  Publication Year  \
# 0  A Proposed Model-driven Approach to Manage Arc...              2019
#
#                                             Abstract  Venue Type  \
# 0  Architectural Technical Debt (ATD) is a metaph...  Conference
#
#                                                Venue  \
# 0  2019 IEEE/ACM International Conference on Tech...
#
#                                        Name of Venue  ...  \
# 0  International Conference on Technical Debt (Te...  ...
#
#   Q4 (Calculate the cost)
#  yes - how?  \
# 0                                  No
#
#                                   Extra (Conclusion)  \
# 0  We have proposed a model-driven approach for m...
#
#                                Extra2 (Related work) Extra 3 (Important work)  \
# 0  Verdecchia in [16] proposed a technique focuse...                      NaN
#
#                                       Strong Aspects  \
# 0  The authors propose an approuch to identify AT...
#
#                                      Weak Aspects  \
# 0  There is calculation formula about cost of ATD
#
#                                     Scientific Rigor  \
# 0  problem characterization: yes, bibliographic r...
#
#                                      Paper relevance Limitations  \
# 0  good due to the authors propose an approuch to...         NaN
#
#                                         Future Works
# 0  Future work will include convolutional neural ...
#
# [1 rows x 29 columns]

# %%
df_sms_extraction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 29 columns):
# Paper Id                                   47 non-null int64
# Citation                                   47 non-null object
# Google Scholar                             47 non-null object
# Authors                                    47 non-null object
# Title                                      47 non-null object
# Publication Year                           47 non-null int64
# Abstract                                   47 non-null object
# Venue Type                                 47 non-null object
# Venue                                      47 non-null object
# Name of Venue                              47 non-null object
# Field                                      47 non-null object
# Key words                                  47 non-null object
# Number of Pages                            47 non-null int64
# Main aim (Goal)                            47 non-null object
# Techniques, approach, methods and tools    45 non-null object
# Kind of reasearch                          44 non-null object
# Q1 (Measure) yes - what?                  40 non-null object
# Q2 (Monitoring) yes - how?                34 non-null object
# Q3 (Techniques and Tools) yes - what?     38 non-null object
# Q4 (Calculate the cost) yes - how?        34 non-null object
# Extra (Conclusion)                         47 non-null object
# Extra2 (Related work)                      35 non-null object
# Extra 3 (Important work)                   19 non-null object
# Strong Aspects                             22 non-null object
# Weak Aspects                               22 non-null object
# Scientific Rigor                           24 non-null object
# Paper relevance                            24 non-null object
# Limitations                                23 non-null object
# Future Works                               23 non-null object
# dtypes: int64(3), object(26)
# memory usage: 10.7+ KB

# %% [markdown]
# ## 1.1 List of Analysed Papers

# %%
for item in zip(list(df_sms_extraction['Citation']), list(df_sms_extraction['Title'])):
    citation = item[0]
    title = ' '.join(item[1].split())
    print('({}, {})'.format(citation, title))
# Out:
# (Perez et al. 2019, A Proposed Model-driven Approach to Manage Architectural Technical Debt Life Cycle)
# (Martini et al 2017, A semi-automated framework for the identification and estimation of Architectural Technical Debt: A comparative case-study on the modularization of a software component)
# (Roveda et al. 2018, Towards an Architectural Debt Index)
# (Snipes et al. 2018, A Case Study of the Effects of Architecture Debt on Software Evolution Effort)
# (Nayebi et al. 2019, A Longitudinal Study of Identifying and Paying Down architecture debt)
# (Feng et al. 2019, Active Hotspot: An Issue-Oriented Model to Monitor Software Evolution and Degradation)
# (Li et al. 2014, An Empirical Investigation of Modularity Metrics for Indicating architectural technical debt)
# (Martini et al. 2016, An Empirically Developed Method to Aid Decisions on Architectural Technical Debt Refactoring: AnaConDebt)
# (Xiao et al. 2016, Identifying and Quantifying Architectural Debt)
# (Verdecchia 2018, Identifying Architectural Technical Debt in Android Applications through Automated Compliance Checking)
# (Zitzweitz et al. 2019, Mitigating Technical and Architectural Debt with Sonargraph Using static analysis to enforce architectural constraints)
# (Martini and Bosch 2017, On the interest of architectural technical debt: Uncovering the contagious debt phenomenon)
# (Fontana et al. 2016, Tool support for evaluating architectural debt of an existing system: An experience report)
# (Li et al. 2015, Architectural Technical Debt Identification based on Architecture Decisions and Change Scenarios)
# (Martini et al. 2014, Architecture Technical Debt: Understanding Causes and a Qualitative Model)
# (Martini et al. 2016, Estimating and Quantifying the Benefits of Refactoring to Improve a Component Modularity: a Case Study)
# (Martini et al. 2018, Identifying and Prioritizing Architectural Debt Through Architectural Smells: A Case Study in a Large Software Company)
# (Cai and Kazman 2016, Software Architecture Health Monitor)
# (Kazman et al. 2015, A Case Study in Locating the Architectural Roots of Technical Debt)
# (Martini and Bosch 2015, Towards Prioritizing Architecture Technical Debt: Information Needs of Architects and Product Owners)
# (Tommasel 2019, Applying Social Network Analysis Techniques to Architectural Smell Prediction)
# (Nord et al. 2012, In Search of a Metric for Managing Architectural Technical Debt)
# (Cai and Kazman 2019, DV8: Automated Architecture Analysis Tool Suites)
# (Skiada et al. 2018, Exploring the Relationship between Software Modularity and Technical Debt)
# (Eliasson et al. 2015, Identifying and Visualizing Architectural Debt and Its Efficiency Interest in the Automotive Domain: A Case Study)
# (Fontana et al. 2016, Technical Debt Indexes provided by tools: a preliminary discussion)
# (MacComark and Sturteant 2016, Technical debt and system architecture: The impact of coupling on defect-related activity)
# (Sas et al. 2019, Investigating Instability Architectural Smells Evolution: An Exploratory Case Study)
# (Fontana et al. 2019, PageRank and criticality of architectural smells)
# (Spinellis and Avgeriou 2019, Evolution of the Unix System Architecture: An Exploratory Case Study)
# (Izurieta et al. 2018, A position study to investigate technical debt associated with security weaknesses)
# (Besker, Martini and Bosch 2017, The pricey bill of technical debt: When and by whom will it be paid?)
# (Ampatzoglou et al 2016, The Perception of Technical Debt in the Embedded Systems Domain: An Industrial Case Study)
# (Martini, Besker and Bosch 2016, The Introduction of Technical Debt Tracking in Large Companies)
# (Aaramaa et al 2017, Requirements volatility in software architecture design: An exploratory case study)
# (Martini et al 2015, Investigating Architectural Technical Debt accumulation and refactoring over time: A multiple-case study)
# (Cai el al 2018, Design Rule Spaces: A New Model for Representing and Analyzing Software Architecture)
# (Bogner et al 2019, Assuring the Evolvability of Microservices: Insights into Industry Practices and Challenges)
# (Ludwig and Webber 2017, Compiling Static Software Metrics for Reliability and Maintainability from GitHub Repositories)
# (Curtis et al 2012, Estimating the principal of an applications technical debt)
# (Curtis et al 2012, Estimating the Size, Cost, and Types of Technical Debt)
# (Kumar et al 2018, Exploring multilateral cloud computing security architectural design debt in terms of technical debt)
# (Hanssen et al 2019, Identifying Scalability Debt in Open Systems)
# (Sierra et al 2019, Is Self-Admitted Technical Debt a Good Indicator of Architectural Divergences?)
# (Bogner et al 2018, Limiting technical debt with maintainability assurance: an industry survey on used techniques and differences with service- and microservice-based systems)
# (Andrzej Zalewski 2017, Risk Appetite in Architectural Decision-Making)
# (Damian A. Tamburri 2019, Software Architecture Social Debt: Managing the Incommunicability Factor)

# %% [markdown]
# ## 1.2 List of Authors

# %%
list_of_authors, list_of_uniques_authors = util.list_of_items(df_data=df_sms_extraction, column_name='Authors')
# Out:
# List of all 161 Authors : ['', '', 'A Tahmid', 'A. Nandakumar', 'Alan MacCormack', 'Alexander Chatzigeorgiou', 'Alexander Chatzigeorgiou', 'Alexander von Zitzewitz', 'Alexandra Szynkarski', 'Alexandra Szynkarski', 'Alfred Zimmermann', 'Alfred Zimmermann', 'Andrea Biaggi', 'Andriy Shapochka', 'Andrzej Zalewski', 'Antonela Tommasel', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Antonio Martini', 'Apostolos Ampatzoglou', 'Apostolos Ampatzoglou', 'Apostolos Ampatzoglou', 'Areti Ampatzoglou', 'Bill Curtis', 'Bill Curtis', 'Boris Perez', 'Chris Carlson', 'Claudia Raibulet', 'Clemente Izurieta', 'Damian A. Tamburri', 'Daniel J. Sturtevant', 'Dario Correal', 'Darius Sas', 'David Rice', 'Di Cui', 'Diomidis Spinellis', 'E Shihab', 'Elvira-Maria Arvanitou', 'Erik Sikander', 'Erik Sikander', 'Francesca Arcelli Fontana', 'Francesca Arcelli Fontana', 'Francesca Arcelli Fontana', 'Francesca Arcelli Fontana', 'Francesca Arcelli Fontana', 'Francesca Arcelli Fontana', 'Francis Chew', 'Frederick Webber', 'G Sierra', 'Geir Kjetil Hanssen', 'Guenther Ruhe', 'Gunnar Brataas', 'Hernan Astudillo', 'Hongzhou Fang', 'Ilaria Pigazzini', 'Ilaria Pigazzini', 'Ioannis Stamelos', 'Ipek Ozkaya', 'Jan Bosch', 'Jan Bosch', 'Jan Bosch', 'Jan Bosch', 'Jan Bosch', 'Jan Bosch', 'Jan Bosch', 'Jay Sappidi', 'Jay Sappidi', 'Jeremy Ludwig', 'Jonas Fritzsch', 'Jonas Fritzsch Jonas Fritzsch', 'Jouni Markkula Jouni Markkula', 'Justus Bogner', 'Justus Bogner', 'Kali Kimball', 'Kari Systa', 'Lu Xiao', 'Lu Xiao', 'Lu Xiao', 'M. Manoj Kumar', 'Maleknaz Nayebi', 
oivo', 'Michel Chaudron', 'N Tsantalis.', 'Nicolas Guelfi', 'Niel Madlani', 'Paris Avgeriou', 'Peggy Skiada', 'Pekka Abrahamsson', 'Peng Liang', 'Philippe Kruchten', 'Qiong Feng', 'Ran Mo', 'Riccardo Roveda', 'Rick Kazman', 'Robert Kaufmann', 'Robert L. Nord', 'Roberto Verdecchia', 'Sam Odeh', 'Samuli Saukkonen', 'Sandun Dasanayake Sandun Dasanayake', 'Sanja Aaramaa', 'Serge Haziyev', 'Stefan Wagner', 'Stefan Wagner Stefan Wagner', 'Stefano Basciano', 'Steven Xu', 'Sunil L Karlekar', 'Terese Besker', 'Tessa Valentien', 'Ting Liu', 'Ulf Eliasson', 'Uwe Zdun', 'Volodymyr Fedak', 'Will Snipes', 'Yuanfang Cai', 'Zengyang Li']

# %%
from collections import Counter

Counter(list_of_authors)
# Out:
# Counter({'': 2,
#          'A Tahmid': 1,
#          'A. Nandakumar': 1,
#          'Alan MacCormack': 1,
#          'Alexander Chatzigeorgiou': 2,
#          'Alexander von Zitzewitz': 1,
#          'Alexandra Szynkarski': 2,
#          'Alfred Zimmermann': 2,
#          'Andrea Biaggi': 1,
#          'Andriy Shapochka': 1,
#          'Andrzej Zalewski': 1,
#          'Antonela Tommasel': 1,
#          'Antonio Martini': 13,
#          'Apostolos Ampatzoglou': 3,
#          'Areti Ampatzoglou': 1,
#          'Bill Curtis': 2,
#          'Boris Perez': 1,
#          'Chris Carlson': 1,
#          'Claudia Raibulet': 1,
#          'Clemente Izurieta': 1,
#          'Damian A. Tamburri': 1,
#          'Daniel J. Sturtevant': 1,
#          'Dario Correal': 1,
#          'Darius Sas': 1,
#          'David Rice': 1,
#          'Di Cui': 1,
#          'Diomidis Spinellis': 1,
#          'E Shihab': 1,
#          'Elvira-Maria Arvanitou': 1,
#          'Erik Sikander': 2,
#          'Francesca Arcelli Fontana': 6,
#          'Francis Chew': 1,
#          'Frederick Webber': 1,
#          'G Sierra': 1,
#          'Geir Kjetil Hanssen': 1,
#          'Guenther Ruhe': 1,
#          'Gunnar Brataas': 1,
#          'Hernan Astudillo': 1,
#          'Hongzhou Fang': 1,
#          'Ilaria Pigazzini': 2,
#          'Ioannis Stamelos': 1,
#          'Ipek Ozkaya': 1,
#          'Jan Bosch': 7,
#          'Jay Sappidi': 2,
#          'Jeremy Ludwig': 1,
#          'Jonas Fritzsch': 1,
#          'Jonas Fritzsch Jonas Fritzsch': 1,
#          'Jouni Markkula Jouni Markkula': 1,
#          'Justus Bogner': 2,
#          'Kali Kimball': 1,
#          'Kari Systa': 1,
#          'Lu Xiao': 3,
#          'M. Manoj Kumar': 1,
#          'Maleknaz Nayebi': 1,
#          'Marco Gonzalez-Rojas': 1,
#          'Marco Zanoni': 3,
#          'Markku Oivo Markku Oivo': 1,
#          'Michel Chaudron': 2,
#          'N Tsantalis.': 1,
#          'Nicolas Guelfi': 1,
#          'Niel Madlani': 2,
#          'Paris Avgeriou': 5,
#          'Peggy Skiada': 1,
#          'Pekka Abrahamsson': 1,
#          'Peng Liang': 2,
#          'Philippe Kruchten': 1,
#          'Qiong Feng': 5,
#          'Ran Mo': 4,
#          'Riccardo Roveda': 4,
#          'Rick Kazman': 7,
#          'Robert Kaufmann': 1,
#          'Robert L. Nord': 1,
#          'Roberto Verdecchia': 1,
#          'Sam Odeh': 1,
#          'Samuli Saukkonen': 1,
#          'Sandun Dasanayake Sandun Dasanayake': 1,
#          'Sanja Aaramaa': 1,
#          'Serge Haziyev': 1,
#          'Stefan Wagner': 1,
#          'Stefan Wagner Stefan Wagner': 1,
#          'Stefano Basciano': 1,
#          'Steven Xu': 1,
#          'Sunil L Karlekar': 1,
#          'Terese Besker': 2,
#          'Tessa Valentien': 1,
#          'Ting Liu': 1,
#          'Ulf Eliasson': 1,
#          'Uwe Zdun': 1,
#          'Volodymyr Fedak': 1,
#          'Will Snipes': 1,
#          'Yuanfang Cai': 7,
#          'Zengyang Li': 2})

# %% [markdown]
# ## 1.3 List of Key words

# %%
list_of_key_words, list_of_uniques_key_words = util.list_of_items(df_data=df_sms_extraction, column_name='Key words')
# Out:
# List of all 190 Key words : ['Android', 'Architectural Debt', 'Architectural Technical Debt Software management Software architecture Agile software development Software life-cycle Qualitative model', 'Architectural deb', 'Architectural debt', 'Architectural smells', 'Architectural technical debt', 'Architectural technical debt', 'Architectural technical debt', 'Architectural technical debt management', 'Architecture Design Decisions', 'Architecture Recovery', 'Architecture Technical Debt', 'Architecture assessment', 'Architecture debt', 'Architecture erosion', 'Automotive engineering', 'Business', 'Complex systems', 'Compliance Checking', 'Computer architecture', 'Computer architecture', 'Computer architecture', 'Context', 'Cost-benefit analysis', 'Criticality', 'Design', 'Development Cost', 'Economics.', 'Empirical Study', 'Estimation', 'Feature Prioritization', 'Grounded Theory', 'History', 'IEEE Newspaper', 'Information Need', 'Longitudinal study', 'Maintainability', 'Management', 'Measurement', 'Measurement', 'Measurement System Software management Refactoring Estimation Technical Debt Modularization Software Architecture', 'Microprocessors', 'Microservices', 'Model-driven architecture', 'Modularization', 'Multilateral cloud security architecture Design smells Technical debt Design debt Cloud computing security Design refactoring', 'Not available', 'Operating Systems.', 'PageRank', 'Prioritization', 'Prioritization Aspects', 'Qualitative data', 'Quantitative data', 'Refactoring', 'Refactoring', 'Refactoring Prioritization', 'Requirement management', 'Self-Admitted Technical Debt', 'Social debt', 'Social networking (online)', 'Software', 'Software', 'Software Architecture', 'Software Architecture', 'Software Architecture', 'Software Architecture', 'Software Architecture', 'Software Architecture', 'Software Architecture.', 'Software Architeture', 'Software Development', 'Software Evolution', 'Software Maintenance', 'Software Maintenance', 'Software Management', 'Software Quality', 'Software Quality', 'Software Quality Analysis Tools', 'Software Re-Engineering', 'Software architecture', 'Software architecture', 'Software architecture', 'Software architecture health monitor', 'Software design', 'Software engineering', 'Software systems', 'Sonar detection', 'Stakeholders', 'Survey', 'Technical Debt', 'Technical Debt', 'Technical Debt', 'Technical Debt', 'Technical Debt', 'Technical Debt', 'Technical Debt', 'Technical Debt Indexes', 'Tool experimentation', 'Unix', 'Visualization', 'Wasted time', 'agile development', 'agile software development', 'agile software development', 'architectural debt', 'architectural debt index', 'architectural smells', 'architectural smells', 'architectural smells evolution', 'architectural technical debt', 'architectural technical debt', 'architectural technical debt', 'architectural technical debt identification', 'architecture', 'architecture debt', 'architecture decision', 'architecture decision-making', 'assurance', 'benchmarking', 'bug localization', 'change management', 'change scenario', 'code smells', 'cohesion', 'commit', 'cost of rework', 'coupling', 'cyclic dependencies', 'defect prediction', 'development speed', 'effort', 'embedded systems', 'evolvability', 'industry', 'industry', 'industry case study', 'influencing factors', 'interviews', 'maintainability', 'metrics', 'micro service-based systems', 'modularity', 'modularity metric', 'multiple case study', 'multiple case-study', 'open banking', 'qualitative model', 'qualitative model', 'quality assurance', 'reliability', 'reverse-engineering', 'risk', 'risk appetite', 'scalability requirements', 'scalability triage', 'service-based systems', 'severity index', 'social debt cost estimation', 'social debt in software architecting', 'sociotechnical phenomena', 'software architecture', 'software architecture', 'software architecture', 'software artchitecture', 'software economics', 'software evolution', 'software life-cycle', 'software metri ...
#
# List of unique 151 Key words : ['Android', 'Architectural Debt', 'Architectural Technical Debt Software management Software architecture Agile software development Software life-cycle Qualitative model', 'Architectural deb', 'Architectural debt', 'Architectural smells', 'Architectural technical debt', 'Architectural technical debt management', 'Architecture Design Decisions', 'Architecture Recovery', 'Architecture Technical Debt', 'Architecture assessment', 'Architecture debt', 'Architecture erosion', 'Automotive engineering', 'Business', 'Complex systems', 'Compliance Checking', 'Computer architecture', 'Context', 'Cost-benefit analysis', 'Criticality', 'Design', 'Development Cost', 'Economics.', 'Empirical Study', 'Estimation', 'Feature Prioritization', 'Grounded Theory', 'History', 'IEEE Newspaper', 'Information Need', 'Longitudinal study', 'Maintainability', 'Management', 'Measurement', 'Measurement System Software management Refactoring Estimation Technical Debt Modularization Software Architecture', 'Microprocessors', 'Microservices', 'Model-driven architecture', 'Modularization', 'Multilateral cloud security architecture Design smells Technical debt Design debt Cloud computing security Design refactoring', 'Not available', 'Operating Systems.', 'PageRank', 'Prioritization', 'Prioritization Aspects', 'Qualitative data', 'Quantitative data', 'Refactoring', 'Refactoring Prioritization', 'Requirement management', 'Self-Admitted Technical Debt', 'Social debt', 'Social networking (online)', 'Software', 'Software Architecture', 'Software Architecture.', 'Software Architeture', 'Software Development', 'Software Evolution', 'Software Maintenance', 'Software Management', 'Software Quality', 'Software Quality Analysis Tools', 'Software Re-Engineering', 'Software architecture', 'Software architecture health monitor', 'Software design', 'Software engineering', 'Software systems', 'Sonar detection', 'Stakeholders', 'Survey', 'Technical Debt', 'Technical Debt Indexes', 'Tool experimentation', 'Unix', 'Visualization', 'Wasted time', 'agile development', 'agile software development', 'architectural debt', 'architectural debt index', 'architectural smells', 'architectural smells evolution', 'architectural technical debt', 'architectural technical debt identification', 'architecture', 'architecture debt', 'architecture decision', 'architecture decision-making', 'assurance', 'benchmarking', 'bug localization', 'change management', 'change scenario', 'code smells', 'cohesion', 'commit', 'cost of rework', 'coupling', 'cyclic dependencies', 'defect prediction', 'development speed', 'effort', 'embedded systems', 'evolvability', 'industry', 'industry case study', 'influencing factors', 'interviews', 'maintainability', 'metrics', 'micro service-based systems', 'modularity', 'modularity metric', 'multiple case study', 'multiple case-study', 'open banking', 'qualitative model', 'quality assurance', 'reliability', 'reverse-engineering', 'risk', 'risk appetite', 'scalability requirements', 'scalability triage', 'service-based systems', 'severity index', 'social debt cost estimation', 'social debt in software architecting', 'sociotechnical phenomena', 'software architecture', 'software artchitecture', 'software economics', 'software evolution', 'software life-cycle', 'software metrics', 'software process improvement', 'software quality', 'software quality control', 'software structural quality', 'softwareproductquality', 'static analysis', 'static code analysis', 'survey', 'technical debt', 'technical debt.', 'technicaldebt', 'total cost of ownership']

# %%
from collections import Counter

Counter(list_of_key_words)
# Out:
# Counter({'Android': 1,
#          'Architectural Debt': 1,
#          'Architectural Technical Debt Software management Software architecture Agile software development Software life-cycle Qualitative model': 1,
#          'Architectural deb': 1,
#          'Architectural debt': 1,
#          'Architectural smells': 1,
#          'Architectural technical debt': 3,
#          'Architectural technical debt management': 1,
#          'Architecture Design Decisions': 1,
#          'Architecture Recovery': 1,
#          'Architecture Technical Debt': 1,
#          'Architecture assessment': 1,
#          'Architecture debt': 1,
#          'Architecture erosion': 1,
#          'Automotive engineering': 1,
#          'Business': 1,
#          'Complex systems': 1,
#          'Compliance Checking': 1,
#          'Computer architecture': 3,
#          'Context': 1,
#          'Cost-benefit analysis': 1,
#          'Criticality': 1,
#          'Design': 1,
#          'Development Cost': 1,
#          'Economics.': 1,
#          'Empirical Study': 1,
#          'Estimation': 1,
#          'Feature Prioritization': 1,
#          'Grounded Theory': 1,
#          'History': 1,
#          'IEEE Newspaper': 1,
#          'Information Need': 1,
#          'Longitudinal study': 1,
#          'Maintainability': 1,
#          'Management': 1,
#          'Measurement': 2,
#          'Measurement System Software management Refactoring Estimation Technical Debt Modularization Software Architecture': 1,
#          'Microprocessors': 1,
#          'Microservices': 1,
#          'Model-driven architecture': 1,
#          'Modularization': 1,
#          'Multilateral cloud security architecture Design smells Technical debt Design debt Cloud computing security Design refactoring': 1,
#          'Not available': 1,
#          'Operating Systems.': 1,
#          'PageRank': 1,
#          'Prioritization': 1,
#          'Prioritization Aspects': 1,
#          'Qualitative data': 1,
#          'Quantitative data': 1,
#          'Refactoring': 2,
#          'Refactoring Prioritization': 1,
#          'Requirement management': 1,
#          'Self-Admitted Technical Debt': 1,
#          'Social debt': 1,
#          'Social networking (online)': 1,
#          'Software': 2,
#          'Software Architecture': 6,
#          'Software Architecture.': 1,
#          'Software Architeture': 1,
#          'Software Development': 1,
#          'Software Evolution': 1,
#          'Software Maintenance': 2,
#          'Software Management': 1,
#          'Software Quality': 2,
#          'Software Quality Analysis Tools': 1,
#          'Software Re-Engineering': 1,
#          'Software architecture': 3,
#          'Software architecture health monitor': 1,
#          'Software design': 1,
#          'Software engineering': 1,
#          'Software systems': 1,
#          'Sonar detection': 1,
#          'Stakeholders': 1,
#          'Survey': 1,
#          'Technical Debt': 7,
#          'Technical Debt Indexes': 1,
#          'Tool experimentation': 1,
#          'Unix': 1,
#          'Visualization': 1,
#          'Wasted time': 1,
#          'agile development': 1,
#          'agile software development': 2,
#          'architectural debt': 1,
#          'architectural debt index': 1,
#          'architectural smells': 2,
#          'architectural smells evolution': 1,
#          'architectural technical debt': 3,
#          'architectural technical debt identification': 1,
#          'architecture': 1,
#          'architecture debt': 1,
#          'architecture decision': 1,
#          'architecture decision-making': 1,
#          'assurance': 1,
#          'benchmarking': 1,
#          'bug localization': 1,
#          'change management': 1,
#          'change scenario': 1,
#          'code smells': 1,
#          'cohesion': 1,
#          'commit': 1,
#          'cost of rework': 1,
#          'coupling': 1,
#          'cyclic dependencies': 1,
#          'defect prediction': 1,
#          'development speed': 1,
#          'effort': 1,
#          'embedded systems': 1,
#          'evolvability': 1,
#          'industry': 2,
#          'industry case study': 1,
#          'influencing factors': 1,
#          'interviews': 1,
#          'maintainability': 1,
#          'metrics': 1,
#          'micro service-based systems': 1,
#          'modularity': 1,
#          'modularity metric': 1,
#          'multiple case study': 1,
#          'multiple case-study': 1,
#          'open banking': 1,
#          'qualitative model': 2,
#          'quality assurance': 1,
#          'reliability': 1,
#          'reverse-engineering': 1,
#          'risk': 1,
#          'risk appetite': 1,
#          'scalability requirements': 1,
#          'scalability triage': 1,
#          'service-based systems': 1,
#          'severity index': 1,
#          'social debt cost estimation': 1,
#          'social debt in software architecting': 1,
#          'sociotechnical phenomena': 1,
#          'software architecture': 3,
#          'software artchitecture': 1,
#          'software economics': 1,
#          'software evolution': 1,
#          'software life-cycle': 1,
#          'software metrics': 2,
#          'software process improvement': 1,
#          'software quality': 1,
#          'software quality control': 1,
#          'software structural quality': 1,
#          'softwareproductquality': 1,
#          'static analysis': 1,
#          'static code analysis': 1,
#          'survey': 2,
#          'technical debt': 8,
#          'technical debt.': 1,
#          'technicaldebt': 1,
#          'total cost of ownership': 1})

# %% [markdown]
# ## 1.4 List of Venues

# %%
list_of_venues = []
for item in list(df_sms_extraction['Name of Venue']): 
    item = ' '.join(item.split())
    list_of_venues.append(item)
list_of_venues.sort()
for each in list_of_venues:
    print(each)
# Out:
# Asia Pacific Software Engineering Conference
# Conference on Software Achitecture
# Conference on Software Architecture and European Conference on Software Architecture
# EE Transactions on Software Engineering
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# Euromicro Conference on Software Engineering and Advanced Applications
# European Conference on Software Architecture
# European Conference on Software Architecture
# IEEE Software
# Information and Software Technology Journal
# International Conference on Automated Software Engineering (ASE)
# International Conference on Mobile Software Engineering and Systems
# International Conference on Software Architecture Companion (ICSA-C)
# International Conference on Software Architecture Workshops (ICSAW)
# International Conference on Software Engineering
# International Conference on Software Engineering
# International Conference on Software Engineering
# International Conference on Software Engineering Companion
# International Conference on Software Engineering: Software Engineering in Practice.
# International Conference on Software Maintenance and Evolution
# International Conference on Software Maintenance and Evolution (ICSME)
# International Conference on Software Maintenance and Evolution (ICSME)
# International Conference on Software and System Process
# International Conference on Systems, Man, and Cybernetics (SMC)
# International Conference on Technical Debt
# International Conference on Technical Debt
# International Conference on Technical Debt (TechDebt)
# International Conference on Technical Debt (TechDebt)
# International Conference on Technical Debt (TechDebt)
# International Conference on Technical Debt (TechDebt)
# International Workshop on Bringing Architectural Design Thinking
# International Workshop on Managing Technical Debt
# International Workshop on Managing Technical Debt (MTD)
# International Workshop on Managing Technical Debt (MTD)
# International Workshop on Managing Technical Debt (MTD)
# Jornal Information and Software Technology
# Journal of Software: Evolution and Process
# Journal of Systems and Software
# SANER
# Springer Nature Singapore
# Symposium on Applied Computing
# TRANSACTIONS ON COMPUTATIONAL SOCIAL SYSTEMS
# international ACM Sigsoft conference on Quality of software architectures

# %% [markdown]
# ## 1.5 The papers below have to be revised:

# %%
df_sms_extraction[df_sms_extraction["Kind of reasearch"].isnull()][['Paper Id', 'Citation', 'Title']]
# Out:
#     Paper Id                Citation  \
# 36        24          Cai el al 2018
# 37        77       Bogner et al 2019
# 38        78  Ludwig and Webber 2017
#
#                                                 Title
# 36  Design Rule Spaces: A New Model for Representi...
# 37  Assuring the Evolvability of Microservices: In...
# 38  Compiling Static Software Metrics for Reliabil...

# %%
df_sms_extraction[df_sms_extraction["Techniques, approach, methods and tools"].isnull()][['Paper Id','Citation', 'Title']]
# Out:
#     Paper Id                 Citation  \
# 21        33         Nord et al. 2012
# 46        40  Damian A. Tamburri 2019
#
#                                                 Title
# 21  In Search of a Metric for Managing Architectur...
# 46  Software Architecture Social Debt: Managing th...

# %%
print(" List of papers to review Scientific Rigor: {}".format(len(df_sms_extraction[df_sms_extraction["Scientific Rigor"].isnull()][['Paper Id','Citation', 'Title']])) )
# Out:
#  List of papers to review Scientific Rigor: 23

# %%
df_sms_extraction[df_sms_extraction["Scientific Rigor"].isnull()][['Paper Id','Citation', 'Title']]
# Out:
#     Paper Id                     Citation  \
# 4          5           Nayebi et al. 2019
# 5          7             Feng et al. 2019
# 6          9               Li et al. 2014
# 7         10          Martini et al. 2016
# 8         13             Xiao et al. 2016
# 11        16       Martini and Bosch 2017
# 13        21               Li et al. 2015
# 15        27          Martini et al. 2016
# 16        30          Martini et al. 2018
# 17        38          Cai and Kazman 2016
# 18        48           Kazman et al. 2015
# 19        47       Martini and Bosch 2015
# 21        33             Nord et al. 2012
# 29        63  Spinellis and Avgeriou 2019
# 34        96           Aaramaa et al 2017
# 35        35           Martini et al 2015
# 36        24               Cai el al 2018
# 37        77            Bogner et al 2019
# 39        81            Curtis et al 2012
# 41        85             Kumar et al 2018
# 43        90            Sierra et al 2019
# 44        91            Bogner et al 2018
# 46        40      Damian A. Tamburri 2019
#
#                                                 Title
# 4   A Longitudinal Study of Identifying and Paying...
# 5   Active Hotspot: An Issue-Oriented Model to Mon...
# 6   An  Empirical Investigation of Modularity Metr...
# 7   An Empirically Developed Method to Aid Decisio...
# 8     Identifying and Quantifying Architectural Debt
# 11  On the interest of architectural technical deb...
# 13  Architectural Technical Debt Identification ba...
# 15  Estimating and Quantifying the Benefits of Ref...
# 16  Identifying and Prioritizing Architectural Deb...
# 17               Software Architecture Health Monitor
# 18  A Case Study in Locating the Architectural Roo...
# 19  Towards Prioritizing Architecture Technical De...
# 21  In Search of a Metric for Managing Architectur...
# 29  Evolution of the Unix System Architecture: An ...
# 34  Requirements volatility in software architectu...
# 35  Investigating Architectural Technical Debt acc...
# 36  Design Rule Spaces: A New Model for Representi...
# 37  Assuring the Evolvability of Microservices: In...
# 39  Estimating the principal of an applications te...
# 41  Exploring multilateral cloud computing securit...
# 43  Is Self-Admitted Technical Debt a Good Indicat...
# 44  Limiting technical debt with maintainability a...
# 46  Software Architecture Social Debt: Managing th...

# %% [markdown]
# ## 1.6 Basic statistic

# %%
publication_per_year = dict(df_sms_extraction['Publication Year'].value_counts())
util.show_bar_plot_complete(publication_per_year, 'Publication per year', x_label='Ano', y_label='Quantidade')

venue_per_type = dict(df_sms_extraction['Venue Type'].value_counts())
util.show_bar_plot_complete(venue_per_type, 'Venue per type', x_label='Tipo', y_label='Quantidade')

number_of_page_grouped = dict(df_sms_extraction['Number of Pages'].value_counts())
util.show_bar_plot_complete(number_of_page_grouped, 'Count of number of pages', x_label='Páginas', y_label='Frequencia')

# %%
util.show_histogram(df_data=df_sms_extraction['Number of Pages'], title="Distribution of Amount of Pages", bins=5)

# %%
df_sms_extraction[df_sms_extraction['Paper Id'] == 22].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 14 to 14
# Data columns (total 29 columns):
# Paper Id                                   1 non-null int64
# Citation                                   1 non-null object
# Google Scholar                             1 non-null object
# Authors                                    1 non-null object
# Title                                      1 non-null object
# Publication Year                           1 non-null int64
# Abstract                                   1 non-null object
# Venue Type                                 1 non-null object
# Venue                                      1 non-null object
# Name of Venue                              1 non-null object
# Field                                      1 non-null object
# Key words                                  1 non-null object
# Number of Pages                            1 non-null int64
# Main aim (Goal)                            1 non-null object
# Techniques, approach, methods and tools    1 non-null object
# Kind of reasearch                          1 non-null object
# Q1 (Measure) yes - what?                  1 non-null object
# Q2 (Monitoring) yes - how?                1 non-null object
# Q3 (Techniques and Tools) yes - what?     1 non-null object
# Q4 (Calculate the cost) yes - how?        1 non-null object
# Extra (Conclusion)                         1 non-null object
# Extra2 (Related work)                      1 non-null object
# Extra 3 (Important work)                   1 non-null object
# Strong Aspects                             1 non-null object
# Weak Aspects                               1 non-null object
# Scientific Rigor                           1 non-null object
# Paper relevance                            1 non-null object
# Limitations                                1 non-null object
# Future Works                               1 non-null object
# dtypes: int64(3), object(26)
# memory usage: 240.0+ bytes

# %%
dados_incompletos = ['Q1 (Measure) yes - what?', 'Q2 (Monitoring) yes - how?', 'Q3 (Techniques and Tools) yes - what?', 'Q4 (Calculate the cost) yes - how?', 'Strong Aspects', 'Weak Aspects', 'Scientific Rigor', 'Paper relevance', 'Limitations', 'Future Works']
for each in dados_incompletos:
    print(each)
# Out:
# Q1 (Measure) yes - what?
# Q2 (Monitoring) yes - how?
# Q3 (Techniques and Tools) yes - what?
# Q4 (Calculate the cost) yes - how?
# Strong Aspects
# Weak Aspects
# Scientific Rigor
# Paper relevance
# Limitations
# Future Works

# %% [markdown]
# ## 1.7 Papers group by Size of pages

# %%
list_of_columns_using_pages = ['Paper Id', 'Citation', 'Number of Pages', 'Title']

mask1 = df_sms_extraction['Number of Pages'] <= 5
df_papers_until_5_pages = df_sms_extraction[mask1][list_of_columns_using_pages]
df_papers_until_5_pages = df_papers_until_5_pages.sort_values(by=['Number of Pages'])

mask2 = (df_sms_extraction['Number of Pages'] > 5) & (df_sms_extraction['Number of Pages'] <= 15)
df_papers_from_6_to_15_pages = df_sms_extraction[mask2][list_of_columns_using_pages]
df_papers_from_6_to_15_pages = df_papers_from_6_to_15_pages.sort_values(by=['Number of Pages'])

mask3 = (df_sms_extraction['Number of Pages'] > 15) & (df_sms_extraction['Number of Pages'] <= 20)
df_papers_from_16_to_20_pages = df_sms_extraction[mask3][list_of_columns_using_pages]
df_papers_from_16_to_20_pages = df_papers_from_16_to_20_pages.sort_values(by=['Number of Pages'])

mask4 = df_sms_extraction['Number of Pages'] > 20
df_papers_over_20_pages = df_sms_extraction[mask4][list_of_columns_using_pages]
df_papers_over_20_pages = df_papers_over_20_pages.sort_values(by=['Number of Pages'])

# %% [markdown]
# ### 1.7.1 Papers size of pages until 5 pages - OK

# %%
print('Papers size of pages until 5 pages: {}'.format( len(df_papers_until_5_pages.sort_values(by=['Number of Pages'])) ))
df_papers_until_5_pages.sort_values(by=['Number of Pages'])
# Out:
# Papers size of pages until 5 pages: 14
#     Paper Id                Citation  Number of Pages  \
# 9         14         Verdecchia 2018                2
# 10        15   Zitzweitz et al. 2019                2
# 22        26     Cai and Kazman 2019                2
# 12        17     Fontana et al. 2016                3
# 3          4      Snipes et al. 2018                4
# 17        38     Cai and Kazman 2016                4
# 23        28      Skiada et al. 2018                4
# 25        44     Fontana et al. 2016                4
# 45        97   Andrzej Zalewski 2017                4
# 0          1       Perez et al. 2019                5
# 30        73    Izurieta et al. 2018                5
# 38        78  Ludwig and Webber 2017                5
# 40        82       Curtis et al 2012                5
# 42        88      Hanssen et al 2019                5
#
#                                                 Title
# 9   Identifying Architectural Technical Debt in An...
# 10  Mitigating Technical and Architectural Debt wi...
# 22  DV8: Automated Architecture Analysis Tool Suites
# 12  Tool support for evaluating architectural debt...
# 3   A Case Study of the Effects of Architecture De...
# 17               Software Architecture Health Monitor
# 23  Exploring the Relationship between Software Mo...
# 25  Technical Debt Indexes provided by tools: a pr...
# 45     Risk Appetite in Architectural Decision-Making
# 0   A Proposed Model-driven Approach to Manage Arc...
# 30  A position study to investigate technical debt...
# 38  Compiling Static Software Metrics for Reliabil...
# 40  Estimating the Size, Cost, and Types of Techni...
# 42       Identifying Scalability Debt in Open Systems

# %%
mask_aux = df_papers_from_6_to_15_pages['Number of Pages'] <= 9 
print('Papers size of pages from 6 to 9 pages: {}'.format( len(df_papers_from_6_to_15_pages[mask_aux].sort_values(by=['Number of Pages'])) ))
df_papers_from_6_to_15_pages[mask_aux].sort_values(by=['Number of Pages'])
# Out:
# Papers size of pages from 6 to 9 pages: 11
#     Paper Id                        Citation  Number of Pages  \
# 33        66  Martini, Besker and Bosch 2016                8
# 32        67          Ampatzoglou et al 2016                8
# 28        52             Fontana et al. 2019                8
# 24        31            Eliasson et al. 2015                8
# 20        20                   Tommasel 2019                8
# 14        22             Martini et al. 2014                8
# 15        27             Martini et al. 2016                8
# 19        47          Martini and Bosch 2015                8
# 2          3              Roveda et al. 2018                9
# 39        81               Curtis et al 2012                9
# 44        91               Bogner et al 2018                9
#
#                                                 Title
# 33  The Introduction of Technical Debt Tracking in...
# 32  The Perception of Technical Debt in the Embedd...
# 28   PageRank and criticality of architectural smells
# 24  Identifying and Visualizing Architectural Debt...
# 20  Applying Social Network Analysis Techniques to...
# 14  Architecture Technical Debt: Understanding Cau...
# 15  Estimating and Quantifying the Benefits of Ref...
# 19  Towards Prioritizing Architecture Technical De...
# 2                 Towards an Architectural Debt Index
# 39  Estimating the principal of an applications te...
# 44  Limiting technical debt with maintainability a...

# %% [markdown]
# ### 1.7.2 Papers size of pages from 10 to 15 pages

# %%
mask_aux2 = df_papers_from_6_to_15_pages['Number of Pages'] > 9
print('Papers size of pages > 9 and < 15: {}'.format( len(df_papers_from_6_to_15_pages[mask_aux2].sort_values(by=['Number of Pages'])) ))
df_papers_from_6_to_15_pages[mask_aux2].sort_values(by=['Number of Pages'])
# Out:
# Papers size of pages > 9 and < 15: 15
#     Paper Id                        Citation  Number of Pages  \
# 13        21                  Li et al. 2015               10
# 43        90               Sierra et al 2019               10
# 7         10             Martini et al. 2016               10
# 6          9                  Li et al. 2014               10
# 34        96              Aaramaa et al 2017               10
# 4          5              Nayebi et al. 2019               10
# 18        48              Kazman et al. 2015               10
# 21        33                Nord et al. 2012               10
# 8         13                Xiao et al. 2016               11
# 27        51                 Sas et al. 2019               11
# 31        69  Besker, Martini and Bosch 2017               11
# 37        77               Bogner et al 2019               11
# 5          7                Feng et al. 2019               12
# 26        43    MacComark and Sturteant 2016               13
# 41        85                Kumar et al 2018               13
#
#                                                 Title
# 13  Architectural Technical Debt Identification ba...
# 43  Is Self-Admitted Technical Debt a Good Indicat...
# 7   An Empirically Developed Method to Aid Decisio...
# 6   An  Empirical Investigation of Modularity Metr...
# 34  Requirements volatility in software architectu...
# 4   A Longitudinal Study of Identifying and Paying...
# 18  A Case Study in Locating the Architectural Roo...
# 21  In Search of a Metric for Managing Architectur...
# 8     Identifying and Quantifying Architectural Debt
# 27  Investigating Instability Architectural Smells...
# 31  The pricey bill of technical debt: When and by...
# 37  Assuring the Evolvability of Microservices: In...
# 5   Active Hotspot: An Issue-Oriented Model to Mon...
# 26  Technical debt and system architecture: The im...
# 41  Exploring multilateral cloud computing securit...

# %% [markdown]
# ### 1.7.3 Papers size of pages from 16 to 20 pages

# %%
print('Papers size of pages from 16 to 20 pages: {}'.format( len(df_papers_from_16_to_20_pages)) )
df_papers_from_16_to_20_pages
# Out:
# Papers size of pages from 16 to 20 pages: 5
#     Paper Id                 Citation  Number of Pages  \
# 1          2       Martini et al 2017               16
# 16        30      Martini et al. 2018               16
# 35        35       Martini et al 2015               17
# 11        16   Martini and Bosch 2017               18
# 46        40  Damian A. Tamburri 2019               18
#
#                                                 Title
# 1   A semi-automated framework for the identificat...
# 16  Identifying and Prioritizing Architectural Deb...
# 35  Investigating Architectural Technical Debt acc...
# 11  On the interest of architectural technical deb...
# 46  Software Architecture Social Debt: Managing th...

# %% [markdown]
# ### 1.7.4 Papers size of more then 20 pages

# %%
print('Papers size of pages from 15 to 20 pages: {}'.format( len(df_papers_over_20_pages.sort_values(by=['Number of Pages'])) ))
df_papers_over_20_pages.sort_values(by=['Number of Pages'])
# Out:
# Papers size of pages from 15 to 20 pages: 2
#     Paper Id                     Citation  Number of Pages  \
# 36        24               Cai el al 2018               27
# 29        63  Spinellis and Avgeriou 2019               31
#
#                                                 Title
# 36  Design Rule Spaces: A New Model for Representi...
# 29  Evolution of the Unix System Architecture: An ...

# %% [markdown]
# # 2 Special analyses

# %%
def macro_wordcloud_content_analysis(path_file, name):
    util.generateWordcloudFromTextFile(path_file, name)
    util.contentAnalysisFromTextFile(path_file)

# %% [markdown]
# ## 2.1 We are creating a text file appended for each analyzed column.

# %%
path_abstracts_file = '../dataset/abstracts.txt'
path_goals_file = '../dataset/goals.txt'
path_conclusions_file = '../dataset/conclusions.txt'
path_futures_file = '../dataset/futures.txt'

path_strong_aspects = '../dataset/strongest.txt'
path_weak_aspects = '../dataset/weaks.txt'
path_scientific_rigor = '../dataset/rigors.txt'
path_paper_relevance = '../dataset/relevances.txt'
path_limitations = '../dataset/limitations.txt'

column_names_df_sms_extraction = df_sms_extraction.columns
abstract_column = column_names_df_sms_extraction[6]
goal_column = column_names_df_sms_extraction[13]
conclusions_column = column_names_df_sms_extraction[20]
strong_aspects_column = column_names_df_sms_extraction[23]
weak_aspects_column = column_names_df_sms_extraction[24]
scientific_rigor_column = column_names_df_sms_extraction[25]
paper_relevance_column = column_names_df_sms_extraction[26]
limitations_column = column_names_df_sms_extraction[27] 
future_column = column_names_df_sms_extraction[28]

util.appendContentsInTextFile(path_abstracts_file, df_sms_extraction[abstract_column])
util.appendContentsInTextFile(path_goals_file, df_sms_extraction[goal_column])
util.appendContentsInTextFile(path_conclusions_file, df_sms_extraction[conclusions_column])
util.appendContentsInTextFile(path_strong_aspects, df_sms_extraction[strong_aspects_column])
util.appendContentsInTextFile(path_weak_aspects, df_sms_extraction[weak_aspects_column])
util.appendContentsInTextFile(path_scientific_rigor, df_sms_extraction[scientific_rigor_column]) 
util.appendContentsInTextFile(path_paper_relevance, df_sms_extraction[paper_relevance_column]) 
util.appendContentsInTextFile(path_limitations, df_sms_extraction[limitations_column])
util.appendContentsInTextFile(path_futures_file, df_sms_extraction[future_column])
# Out:
# The file ../dataset/abstracts.txt was created with sucess!
# The ../dataset/abstracts.txt has appended all abstract content with sucess!
# The file ../dataset/goals.txt was created with sucess!
# The ../dataset/goals.txt has appended all abstract content with sucess!
# The file ../dataset/conclusions.txt was created with sucess!
# The ../dataset/conclusions.txt has appended all abstract content with sucess!
# The file ../dataset/strongest.txt was created with sucess!
# The ../dataset/strongest.txt has appended all abstract content with sucess!
# The file ../dataset/weaks.txt was created with sucess!
# The ../dataset/weaks.txt has appended all abstract content with sucess!
# The file ../dataset/rigors.txt was created with sucess!
# The ../dataset/rigors.txt has appended all abstract content with sucess!
# The file ../dataset/relevances.txt was created with sucess!
# The ../dataset/relevances.txt has appended all abstract content with sucess!
# The file ../dataset/limitations.txt was created with sucess!
# The ../dataset/limitations.txt has appended all abstract content with sucess!
# The file ../dataset/futures.txt was created with sucess!
# The ../dataset/futures.txt has appended all abstract content with sucess!

# %%
# Allows NLP (Natural Language Process) for each content in dataframe
util.loadSupportTokenization()
# Out:
# Starting download punkt to suport tokeninzing...
# Download concluído.
# Unzip concluído.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/armandosoaressousa/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## 2.2 Generate the wordcloud of abstracts content and content analysis

# %%
macro_wordcloud_content_analysis(path_abstracts_file, 'abstracts')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 455)
# ('and', 291)
# ('debt', 140)
# ('that', 116)
# ('architectural', 102)
# ('technical', 94)
# ('software', 93)
# ('this', 74)
# ('for', 69)
# ('architecture', 65)
# ('are', 57)
# ('system', 49)
# ('can', 47)
# ('with', 42)
# ('study', 41)
# ('design', 38)
# ('has', 34)
# ('development', 33)
# ('from', 33)
# ('these', 29)
# ('systems', 29)
# ('maintenance', 28)
# ('have', 28)
# ('their', 27)
# ('project', 26)
# ('code', 26)
# ('which', 26)
# ('results', 26)
# ('been', 24)
# ('not', 24)
# ('quality', 24)
# ('paper', 24)
# ('how', 24)
# ('time', 23)
# ('case', 23)
# ('atd', 21)
# ('refactoring', 21)
# ('large', 20)
# ('interest', 20)
# ('its', 19)
# ('such', 19)
# ('different', 19)
# ('smells', 19)
# ('source', 19)
# ('analysis', 19)
# ('over', 18)
# ('decisions', 17)
# ('architects', 17)
# ('files', 17)
# ('evolution', 17)
# ('approach', 16)
# ('identified', 16)
# ('issues', 16)
# ('metrics', 16)
# ('they', 16)
# ('tools', 16)
# ('but', 15)
# ('impact', 15)
# ('was', 15)
# ('conducted', 15)
# ('costs', 15)
# ('flaws', 15)
# ('companies', 15)
# ('most', 15)
# ('however', 14)
# ('model', 14)
# ('other', 14)
# ('research', 14)
# ('identify', 14)
# ('into', 14)
# ('more', 14)
# ('using', 14)
# ('both', 14)
# ('practitioners', 14)
# ('components', 13)
# ('show', 13)
# ('based', 13)
# ('our', 13)
# ('requirements', 13)
# ('used', 12)
# ('business', 12)
# ('modularity', 12)
# ('method', 12)
# ('maintainability', 12)
# ('important', 12)
# Número total de palavras é 8076
# Número de palavras únicas é 1652

# %% [markdown]
# ## 2.3 Generate the wordcloud of goals content and content analysis

# %%
macro_wordcloud_content_analysis(path_goals_file, 'goals')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the',
# ('impact', 25)
# ('decisions', 25)
# ('smells', 25)
# ('tools', 25)
# ('design', 24)
# ('process', 24)
# ('research', 24)
# ('work', 24)
# ('were', 23)
# ('tool', 23)
# ('results', 23)
# ('identify', 23)
# ('index', 23)
# ('each', 23)
# ('would', 23)
# ('data', 23)
# ('information', 22)
# ('but', 22)
# ('future', 22)
# ('systems', 22)
# ('maintenance', 22)
# ('new', 22)
# ('issues', 22)
# ('using', 21)
# ('practitioners', 21)
# ('costs', 21)
# ('plan', 20)
# ('value', 20)
# ('has', 20)
# ('evolution', 20)
# ('them', 20)
# ('large', 20)
# ('first', 19)
# ('provide', 19)
# ('between', 19)
# ('analysis', 19)
# Número total de palavras é 12649
# Número de palavras únicas é 2154

# %% [markdown]
# ## 2.5 Generate the wordcloud of future work content and content analysis

# %%
macro_wordcloud_content_analysis(path_futures_file, 'future_works')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 75)
# ('and', 34)
# ('that', 15)
# ('future', 13)
# ('for', 11)
# ('are', 10)
# ('smells', 9)
# ('plan', 8)
# ('architectural', 8)
# ('other', 8)
# ('with', 8)
# ('also', 7)
# ('would', 7)
# ('debt', 7)
# ('work', 6)
# ('such', 6)
# ('this', 6)
# ('code', 6)
# ('atd', 5)
# ('quality', 5)
# ('study', 5)
# ('software', 5)
# ('can', 5)
# ('they', 5)
# ('not', 5)
# ('include', 4)
# ('tool', 4)
# ('different', 4)
# ('finally', 4)
# ('impact', 4)
# ('process', 4)
# ('which', 4)
# ('issues', 4)
# ('tools', 4)
# ('when', 4)
# ('refactoring', 4)
# ('what', 4)
# ('our', 4)
# ('research', 4)
# ('associated', 4)
# ('from', 4)
# ('data', 4)
# ('will', 3)
# ('into', 3)
# ('methods', 3)
# ('like', 3)
# ('could', 3)
# ('analysis', 3)
# ('project', 3)
# ('projects', 3)
# ('investigation', 3)
# ('effects', 3)
# ('have', 3)
# ('more', 3)
# ('interest', 3)
# ('investigate', 3)
# ('part', 3)
# ('see', 3)
# ('metrics', 3)
# ('studies', 3)
# ('architecture', 3)
# ('maintenance', 3)
# ('practitioners', 3)
# ('difficult', 3)
# ('made', 2)
# ('system', 2)
# ('repayment', 2)
# ('should', 2)
# ('including', 2)
# ('performance', 2)
# ('according', 2)
# ('issue', 2)
# ('extend', 2)
# ('fully', 2)
# ('evaluate', 2)
# ('via', 2)
# ('consider', 2)
# ('provide', 2)
# ('developed', 2)
# ('tectural', 2)
# ('history', 2)
# ('further', 2)
# ('remains', 2)
# ('development', 2)
# Número total de palavras é 1119
# Número de palavras únicas é 469

# %% [markdown]
# ## 2.6 Generate extra wordcloud and content analysis

# %%
macro_wordcloud_content_analysis(path_strong_aspects, 'strong')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the',